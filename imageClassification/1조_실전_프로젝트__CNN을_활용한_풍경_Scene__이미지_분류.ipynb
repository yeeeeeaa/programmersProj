# %% [markdown]
# ### <b>실전 프로젝트 - CNN을 활용한 풍경(Scene) 이미지 분류</b>
#
# * 한 장의 풍경 이미지가 주어졌을 때, 어떠한 카테고리(category)에 속하는지 맞히는 <b>분류 모델</b>을 만드세요.
# * 다음의 세 가지 대표적인 CNN 모델을 실습합니다.
#     1. [LeNet (1998)](http://yann.lecun.com/exdb/publis/pdf/lecun-98.pdf)
#     2. [AlexNet (2012 NIPS)](https://papers.nips.cc/paper/2012/file/c399862d3b9d6b76c8436e924a68c45b-Paper.pdf)
#     3. [ResNet (2016 CVPR)](https://arxiv.org/abs/1512.03385)
# * 성능을 올릴 수 있는 두 가지 심화 기법을 실습합니다.
#     1. [Mixup (ICLR 2018)](https://arxiv.org/abs/1710.09412): 데이터 증진 기법의 일종으로 정확도를 높입니다.
#     2. Transfer Learning: 학습 속도와 정확도를 모두 향상시킬 수 있습니다.
# * 본 프로젝트는 <b>총 7개의 문제</b>로 구성됩니다.
#     * <b>Problem</b>이라고 명시된 부분의 소스코드만 작성합니다.
#     * <b>알아보기</b>라고 명시된 부분은 단순히 읽고 실행하면 됩니다.
#     * 단계적으로 문제를 풀어나가는 과정에서 CNN 기반의 고성능 분류 모델을 학습하는 방법을 이해할 수 있습니다.
# * (참고) 본 실습 코드에서는 빠른 결과 도출을 위해 30~50 epoch 정도만 학습합니다.
#     * 풍경 데이터셋에 대하여 완전히 학습시키기 위해서는 100 epoch 이상의 학습이 필요합니다.

# %% [markdown]
# #### <b>(알아보기) 지난 프로젝트 Review</b>
#
# * 지난 프로젝트에서는 Scene Classification 데이터셋에 대하여 간단한 기계학습 모델을 학습했습니다.
#     1. 선형 분류 모델(Linear Models for Classification)
#     2. KNN (K-Nearest Neighbors)
# * 하지만, 두 기법 모두 정확도(accuracy)가 <b>60% 미만</b>으로 낮게 나온다는 <b>한계점</b>이 존재했습니다.
# * 본 실습에서는 CNN을 이용해 정확도를 <b>최소한 90% 이상으로</b> 높입니다.
#     * 실제로 현업에서 많이 사용되는 테크닉을 이용해 최대한 정확도를 끌어올려 봅시다.

# %% [markdown]
# #### <b>Problem 1. 데이터셋 다운로드 및 분석하기</b>
#
# * [PyTorch용 Scene Classification 데이터셋 저장소](https://github.com/ndb796/Scene-Classification-Dataset-Split)
#     * 참고: [원본 Kaggle 데이터셋 링크](https://www.kaggle.com/nitishabharathi/scene-classification)
#     * 본 데이터셋은 <b>저작권이 없는(No Copyright)</b> [CC0: Public Domain](https://creativecommons.org/publicdomain/zero/1.0/) 라이센스를 따라므로, 자유롭게 변형할 수 있습니다.
# * PyTorch에서 곧바로 불러와 사용할 수 있도록 구성된 데이터셋입니다.
# * 다음의 명령어를 이용해 데이터셋을 다운로드할 수 있습니다.
#
# <pre>
# # 깃허브에서 데이터셋 다운로드하기
# !git clone https://github.com/ndb796/Scene-Classification-Dataset-Split
# # 폴더 안으로 이동
# %cd Scene-Classification-Dataset-Split
# </pre>

# %%
# 깃허브에서 데이터셋 다운로드하기
# !git clone https://github.com/ndb796/Scene-Classification-Dataset-Split
# 폴더 안으로 이동
# %cd Scene-Classification-Dataset-Split
# Out:
# Cloning into 'Scene-Classification-Dataset-Split'...
# remote: Enumerating objects: 17038, done.
# remote: Total 17038 (delta 0), reused 0 (delta 0), pack-reused 17038
# Receiving objects: 100% (17038/17038), 136.02 MiB | 27.62 MiB/s, done.
# /content/Scene-Classification-Dataset-Split

# %% [markdown]
# #### <b>(알아보기) 데이터셋 설명</b>
#
# * 본 PyTorch용 장면(scene) 데이터셋은 17,034개의 다양한 <b>자연 경치(scene)</b> 이미지로 구성되어 있습니다.
# * 총 6개의 클래스(class)로 구성됩니다.
#
# <pre>
# 클래스 0. 빌딩(buildings)
# 클래스 1. 숲(forests)
# 클래스 2. 빙하(glacier)
# 클래스 3. 산(mountains)
# 클래스 4. 바다(sea)
# 클래스 5. 거리(street)
# </pre>
#
# * 각 이미지는 공통적으로 64 X 64 크기를 가집니다.
# * 데이터셋 폴더 구성은 다음과 같습니다.
#
# <pre>
# Dataset/
#     train/
#         buildings/
#         forests/
#         glacier/
#         mountains/
#         sea/
#         streat/
#     val/
#         buildings/
#         forests/
#         glacier/
#         mountains/
#         sea/
#         streat/
# </pre>

# %% [markdown]
# #### <b>(알아보기) 클래스별 학습 이미지 개수 출력하기</b>
#
# * 클래스별 데이터의 개수를 계산합니다.
#     * os 라이브러리의 os.listdir()를 이용하여 이미지 폴더에 존재하는 파일 이름 목록을 얻을 수 있습니다.
#     * 클래스의 개수는 6개입니다.
# * 총 학습 데이터의 개수는 13,627개입니다.
#
# <pre>
# 클래스 0. 빌딩(buildings): 2,105개
# 클래스 1. 숲(forests): 2,205개
# 클래스 2. 빙하(glacier): 2,363개
# 클래스 3. 산(mountains): 2,438개
# 클래스 4. 바다(sea): 2,224개
# 클래스 5. 거리(street): 2,292개
# </pre>
#
# * 총 검증 데이터의 개수는 3,407개입니다.
#
# <pre>
# 클래스 0. 빌딩(buildings): 523개
# 클래스 1. 숲(forests): 540개
# 클래스 2. 빙하(glacier): 594개
# 클래스 3. 산(mountains): 599개
# 클래스 4. 바다(sea): 560개
# 클래스 5. 거리(street): 591개
# </pre>

# %%
import os


classes = ['buildings', 'forests', 'glacier', 'mountains', 'sea', 'street']
train_path = 'train/'
val_path = 'val/'

print("[ 학습 데이터셋 ]")
for i in range(6):
    print(f'클래스 {i}의 개수: {len(os.listdir(train_path + classes[i]))}')

print("[ 검증 데이터셋 ]")
for i in range(6):
    print(f'클래스 {i}의 개수: {len(os.listdir(val_path + classes[i]))}')
# Out:
# [ 학습 데이터셋 ]
# 클래스 0의 개수: 2105
# 클래스 1의 개수: 2205
# 클래스 2의 개수: 2363
# 클래스 3의 개수: 2438
# 클래스 4의 개수: 2224
# 클래스 5의 개수: 2292
# [ 검증 데이터셋 ]
# 클래스 0의 개수: 523
# 클래스 1의 개수: 540
# 클래스 2의 개수: 594
# 클래스 3의 개수: 599
# 클래스 4의 개수: 560
# 클래스 5의 개수: 591

# %% [markdown]
# #### <b>(알아보기) 데이터셋 불러오기</b>
#
# * PyTorch의 <b>ImageFolder 라이브러리</b>를 이용하여 <b>자신만의 데이터셋</b>을 불러올 수 있습니다.
# * ImageFolder 라이브러리는 다음과 같이 <b>계층적인 폴더 구조</b>에서 데이터셋을 불러올 때 사용할 수 있습니다.
#     * 각 클래스명(class name)으로 된 폴더에 여러 장의 이미지가 들어가 있는 구조입니다.
#
# <pre>
# dataset/
#     class 0/
#         0.jpg
#         1.jpg
#         ...
#     class 1/
#         0.jpg
#         1.jpg
#         ...
#     ...
#     class 9/
#         0.jpg
#         1.jpg
#         ...
# </pre>
#
# * 기본적인 <b>데이터 증진(data augmentation)</b> 기법을 사용합니다.
#     * [RandomResizedCrop()](https://pytorch.org/vision/stable/transforms.html): 학습 시기에 랜덤으로 이미지의 일부를 잘라내어 특정 크기로 변형합니다.
#     * [RandomHorizontalFlip()](https://pytorch.org/vision/stable/transforms.html): 학습 시기에 랜덤으로 이미지를 좌우 반전합니다.
# * <b>정규화(normalization)를</b> 진행합니다.
#     * 일반적으로 많이 사용되는 ImageNet 데이터셋의 설정을 이용합니다.

# %%
import torch
from torchvision import datasets, transforms


device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu") # device object

transforms_train = transforms.Compose([
    transforms.RandomResizedCrop((64, 64)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) # 정규화(normalization)
])

transforms_val = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

train_dataset = datasets.ImageFolder(train_path, transforms_train)
val_dataset = datasets.ImageFolder(val_path, transforms_val)

train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=2)
val_dataloader = torch.utils.data.DataLoader(val_dataset, batch_size=32, shuffle=True, num_workers=2)

print('Training dataset size:', len(train_dataset))
print('Validation dataset size:', len(val_dataset))

class_names = train_dataset.classes
print('Class names:', class_names)
# Out:
# Training dataset size: 13627
# Validation dataset size: 3407
# Class names: ['buildings', 'forests', 'glacier', 'mountains', 'sea', 'street']

# %% [markdown]
# #### <b>(알아보기) 이미지 시각화하기</b>
#
# * PyTorch로 불러온 데이터(torch.Tensor 객체)를 시각화해 봅시다.
# * Google Colab에 출력하기 위해서 NumPy 형태로 변형한 뒤에 Matplotlib을 이용합니다.
#     * torch.Tensor는 (Channel, Height, Width) 형식을 가집니다.
#     * numpy 객체는 (Height, Width, Channel) 형식을 가집니다.

# %%
import torchvision
import numpy as np
import matplotlib.pyplot as plt


# 화면에 출력되는 이미지 크기를 적절하게 조절하기
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 60
plt.rcParams.update({'font.size': 20})


def imshow(image, title):
    # torch.Tensor => numpy 변환하기
    image = image.numpy().transpose((1, 2, 0))
    # 이미지 정규화(normalization) 해제하기
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    image = np.clip(image, 0, 1)
    # 화면에 이미지 출력하기
    plt.imshow(image)
    plt.title(title)
    plt.show()


# 학습 데이터셋에서 하나의 배치를 불러와 보기
iterator = iter(train_dataloader)

# 현재 배치에 포함된 이미지를 출력하기
inputs, classes = next(iterator)
out = torchvision.utils.make_grid(inputs[:4])
imshow(out, title=[class_names[x] for x in classes[:4]])

# %% [markdown]
# #### <b>Problem 2. Convolution 연산 이해하기</b>
#
# * Convolution 연산의 동작 원리를 이해할 필요가 있습니다.
# * <b>[그림 예시]</b> 아래 그림에서는 stride가 1이고, padding이 0일 때의 Convolution 연산 예시를 보입니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <hr>
#
# * 입력 데이터의 높이: $height$
# * 입력 데이터의 너비: $width$
# * 필터의 높이: $filter\_height$
# * 필터의 너비: $filter\_width$
# * 스트라이드(stride): $stride$
# * 패딩 크기: $padding$
#
# <hr>
#
# * Convolution 연산 이후의 출력 차원은 다음과 같은 공식으로 계산할 수 있습니다. (나누기할 때 소수점 아래 버림)
#     * 출력 높이(output height) = $(height + 2 * padding - filter\\_height) / stride + 1$
#     * 출력 너비(output width) = $(width + 2 * padding - filter\\_width) / stride + 1$
#
# * <b>[문제]</b> 다음의 각 경우에 대하여 Convolution 연산을 수행한 뒤의 출력 차원을 쓰세요.
#     1. $height=32$, $width=32$, $filter\\_height=5$, $filter\\_width=5$, $stride=2$, $padding=2$일 때 → 출력 높이: 16 출력 너비: 16
#     2. $height=64$, $width=64$, $filter\\_height=3$, $filter\\_width=3$, $stride=1$, $padding=1$일 때 → 출력 높이: 64 출력 너비: 64
#     3. $height=16$, $width=16$, $filter\\_height=4$, $filter\\_width=4$, $stride=2$, $padding=1$일 때 → 출력 높이: 8 출력 너비: 8
#     4. $height=60$, $width=45$, $filter\\_height=8$, $filter\\_width=5$, $stride=3$, $padding=1$일 때 → 출력 높이: 19 출력 너비: 15
#
# * (Hint) 다음과 같은 Python 코드를 사용하여 간단히 계산할 수 있습니다.
#
# <pre>
# height = 16
# width = 16
# filter_height = 4
# filter_width = 4
# stride = 2
# padding = 1
#
# output_height = (height + 2 * padding - filter_height) // stride + 1
# output_width = (width + 2 * padding - filter_width) // stride + 1
#
# print('출력 높이:', output_height, '출력 너비:', output_width)
# </pre>
#
# * 실행 결과 예시
#
# <pre>
# 출력 높이: 8 출력 너비: 8
# </pre>

# %%
height = [32, 64, 16, 60]
width = [32, 64, 16, 45]
filter_height = [5, 3, 4, 8]
filter_width = [5, 3, 4, 5]
stride = [2, 1, 2, 3]
padding = [2, 1, 1, 1]

for i in range(4):
  output_height = (height[i] + 2 * padding[i] - filter_height[i]) // stride[i] + 1
  output_width = (width[i] + 2 * padding[i] - filter_width[i]) // stride[i] + 1
  print('출력 높이:', output_height, '출력 너비:', output_width)
# Out:
# 출력 높이: 16 출력 너비: 16
# 출력 높이: 64 출력 너비: 64
# 출력 높이: 8 출력 너비: 8
# 출력 높이: 19 출력 너비: 15

# %% [markdown]
# #### <b>(알아보기) Lenet 아키텍처 이해하기</b>
#
# * 기본적인 LeNet 아키텍처를 이해할 수 있습니다.
#     * Convolutional Neural Network를 최초로(1998년) 적용한 간단한 아키텍처입니다.
#     * Convolution 연산과 Pooling 연산이 사용됩니다.
# * <b>아래의 표</b>와 같은 아키텍처를 PyTorch로 구현한 것을 확인해 봅시다.
#     * 원본 논문과 완전히 동일하지는 않지만, 핵심 아이디어를 잘 표현한 아키텍처입니다.
#     * PyTorch에서는 모델에 별도로 Softmax 레이어를 두지 않고, 학습할 때 nn.CrossEntropyLoss()를 사용하는 것이 일반적입니다.

# %% [markdown]
# Layer | Type | Specification
# :-: | :-: | ---
# 1 | Input | image size: 3 X 64 X 64
# 2 | Convolution | # of kernel: 20, kernel size: 5 X 5, stride: 1, zero padding: 0
# 3 | Pooling | max pooling, kernel size: 2 X 2, stride: 2
# 4 | Convolution | # of kernel: 50, kernel size: 5 X 5, stride: 1, zero padding: 0
# 5 | Pooling | max pooling, kernel size: 2 X 2, stride: 2
# 6 | Fully Connected | # of neuron: 500
# 7 | Activation | ReLU
# 8 | Fully Connected | # of neuron: 6
# 9 | Softmax | 6 classes

# %%
import torch.nn as nn
import torch.nn.functional as F


class LeNet(nn.Module):
    def __init__(self):
        super(LeNet, self).__init__()
        # → 차원(dimension): (3 x 64 x 64)
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=20, kernel_size=5, stride=1, padding=0)
        # → 차원(dimension): (20 x 60 x 60)
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)
        # → 차원(dimension): (20 x 30 x 30)
        self.conv2 = nn.Conv2d(in_channels=20, out_channels=50, kernel_size=5, stride=1, padding=0)
        # → 차원(dimension): (50 x 26 x 26)
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)
        # → 차원(dimension): (50 x 13 x 13)
        self.fc1 = nn.Linear(50 * 13 * 13, 500)
        # → 차원(dimension): (500)
        self.fc2 = nn.Linear(500, 6)
        # → 차원(dimension): (6)

    def forward(self, x):
        x = self.pool1(self.conv1(x))
        x = self.pool2(self.conv2(x))
        x = torch.flatten(x, 1) # 배치(batch)를 제외한 모든 차원 flatten하기
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %% [markdown]
# #### <b>(알아보기) 학습 및 평가 함수 이해하기</b>
#
# * 별도의 학습(train) 함수와 평가(validate) 함수를 작성합니다.

# %%
def train(net, epoch, optimizer, criterion, train_dataloader):
    print('[ Train epoch: %d ]' % epoch)
    net.train() # 모델을 학습 모드로 설정
    train_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(train_dataloader):
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad() # 기울기(gradient) 초기화

        outputs = net(inputs) # 모델 입력하여 결과 계산
        loss = criterion(outputs, targets) # 손실(loss) 값 계산
        loss.backward() # 역전파를 통해 기울기(gradient) 계산

        optimizer.step() # 계산된 기울기를 이용해 모델 가중치 업데이트
        train_loss += loss.item()
        _, predicted = outputs.max(1)

        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()

    print('Train accuarcy:', 100. * correct / total)
    print('Train average loss:', train_loss / total)
    return (100. * correct / total, train_loss / total)


def validate(net, epoch, val_dataloader):
    print('[ Validation epoch: %d ]' % epoch)
    net.eval() # 모델을 평가 모드로 설정
    val_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(val_dataloader):
        inputs, targets = inputs.to(device), targets.to(device)

        outputs = net(inputs) # 모델 입력하여 결과 계산
        val_loss += criterion(outputs, targets).item()
        _, predicted = outputs.max(1)

        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()

    print('Accuarcy:', 100. * correct / total)
    print('Average loss:', val_loss / total)
    return (100. * correct / total, val_loss / total)

# %% [markdown]
# #### <b>(알아보기) LeNet 학습하기</b>
#
# * 앞서 정의한 LeNet 네트워크를 학습합니다.
# * 학습률(learning rate)을 수정해보면서 결과를 확인해 봅시다.
#     * 만약 학습률이 너무 크다면, 발산하여 손실(loss) 값이 NaN으로 나오며 학습이 안 될 수 있습니다.

# %%
import time
import torch.optim as optim


net = LeNet()
net = net.to(device)

epoch = 30
learning_rate = 0.002
file_name = "LeNet.pt"

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)

train_result = []
val_result = []

start_time = time.time() # 시작 시간

for i in range(epoch):
    train_acc, train_loss = train(net, i, optimizer, criterion, train_dataloader) # 학습(training)
    val_acc, val_loss = validate(net, i + 1, val_dataloader) # 검증(validation)

    # 학습된 모델 저장하기
    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print(f'Model saved! (time elapsed: {time.time() - start_time})')

    # 현재 epoch에서의 정확도(accuracy)와 손실(loss) 값 저장하기
    train_result.append((train_acc, train_loss))
    val_result.append((val_acc, val_loss))
# Out:
# [ Train epoch: 0 ]
# Train accuarcy: 50.42929478241726
# Train average loss: 0.039766479480675104
# [ Validation epoch: 1 ]
# Accuarcy: 62.07807455239213
# Average loss: 0.030662815627514318
# Model saved! (time elapsed: 22.234983444213867)
# [ Train epoch: 1 ]
# Train accuarcy: 58.38409040874734
# Train average loss: 0.03378740816252102
# [ Validation epoch: 2 ]
# Accuarcy: 67.7428823011447
# Average loss: 0.027148271992579562
# Model saved! (time elapsed: 37.16646456718445)
# [ Train epoch: 2 ]
# Train accuarcy: 61.18001027372129
# Train average loss: 0.031643831350224784
# [ Validation epoch: 3 ]
# Accuarcy: 68.6527737012034
# Average loss: 0.02621794010244369
# Model saved! (time elapsed: 52.33034825325012)
# [ Train epoch: 3 ]
# Train accuarcy: 62.91186614808836
# Train average loss: 0.030762458176520825
# [ Validation epoch: 4 ]
# Accuarcy: 71.35309656589375
# Average loss: 0.024569211728348212
# Model saved! (time elapsed: 68.59339880943298)
# [ Train epoch: 4 ]
# Train accuarcy: 64.86387319292581
# Train average loss: 0.029364207113376145
# [ Validation epoch: 5 ]
# Accuarcy: 70.44320516583504
# Average loss: 0.024958546022743222
# Model saved! (time elapsed: 83.49677610397339)
# [ Train epoch: 5 ]
# Train accuarcy: 65.59771042782711
# Train average loss: 0.028748953030570776
# [ Validation epoch: 6 ]
# Accuarcy: 73.73055474024068
# Average loss: 0.022874453068129436
# Model saved! (time elapsed: 98.37528371810913)
# [ Train epoch: 6 ]
# Train accuarcy: 66.44896162031262
# Train average loss: 0.028030017623899967
# [ Validation epoch: 7 ]
# Accuarcy: 75.1981215145289
# Average loss: 0.022395891434011973
# Model saved! (time elapsed: 113.26234722137451)
# [ Train epoch: 7 ]
# Train accuarcy: 67.92397446246423
# Train average loss: 0.027310041712237932
# [ Validation epoch: 8 ]
# Accuarcy: 74.69914881127092
# Average loss: 0.022591892569723597
# Model saved! (time elapsed: 128.1534276008606)
# [ Train epoch: 8 ]
# Train accuarcy: 67.91663609011522
# Train average loss: 0.027158969720338808
# [ Validation epoch: 9 ]
# Accuarcy: 72.9674200176108
# Average loss: 0.023923144999717667
# Model saved! (time elapsed: 142.9897313117981)
# [ Train epoch: 9 ]
# Train accuarcy: 68.7605489102517
# Train average loss: 0.02639962438967727
# [ Validation epoch: 10 ]
# Accuarcy: 73.6425007337834
# Average loss: 0.02329879171658654
# Model saved! (time elapsed: 158.99634957313538)
# [ Train epoch: 10 ]
# Train accuarcy: 69.21552799589051
# Train average loss: 0.026283128845759042
# [ Validation epoch: 11 ]
# Accuarcy: 74.17082477252715
# Average loss: 0.022491357842253073
# Model saved! (time elapsed: 174.21010828018188)
# [ Train epoch: 11 ]
# Train accuarcy: 69.91267336904674
# Train average loss: 0.02561758694920281
# [ Validation epoch: 12 ]
# Accuarcy: 73.43704138538304
# Average loss: 0.022918803594943048
# Model saved! (time elapsed: 189.34386348724365)
# [ Train epoch: 12 ]
# Train accuarcy: 69.67050708152932
# Train average loss: 0.025858122201783646
# [ Validation epoch: 13 ]
# Accuarcy: 76.7830936307602
# Average loss: 0.020680170045908084
# Model saved! (time elapsed: 204.22479724884033)
# [ Train epoch: 13 ]
# Train accuarcy: 70.17685477361121
# Train average loss: 0.025286388701647948
# [ Validation epoch: 14 ]
# Accuarcy: 74.90460815967127
# Average loss: 0.021775584146358554
# Model saved! (time elapsed: 219.14335680007935)
# [ Train epoch: 14 ]
# Train accuarcy: 70.25757686945036
# Train average loss: 0.025298819445615434
# [ Validation epoch: 15 ]
# Accuarcy: 76.75374229527444
# Average loss: 0.021211795148032134
# Model saved! (time elapsed: 234.07918500900269)
# [ Train epoch: 15 ]
# Train accuarcy: 70.85932340206942
# Train average loss: 0.024940176618381774
# [ Validation epoch: 16 ]
# Accuarcy: 77.6049310243616
# Average loss: 0.020269365439430375
# Model saved! (time elapsed: 249.8545663356781)
# [ Train epoch: 16 ]
# Train accuarcy: 70.80061642327732
# Train average loss: 0.024671740861109438
# [ Validation epoch: 17 ]
# Accuarcy: 78.16260639859114
# Average loss: 0.019935262607345492
# Model saved! (time elapsed: 265.07650661468506)
# [ Train epoch: 17 ]
# Train accuarcy: 71.76928157334703
# Train average loss: 0.024239270448894644
# [ Validation epoch: 18 ]
# Accuarcy: 76.40152626944526
# Average loss: 0.021494098132329144
# Model saved! (time elapsed: 279.9575960636139)
# [ Train epoch: 18 ]
# Train accuarcy: 71.71057459455493
# Train average loss: 0.024156938649732035
# [ Validation epoch: 19 ]
# Accuarcy: 76.7830936307602
# Average loss: 0.02059218227111037
# Model saved! (time elapsed: 294.846622467041)
# [ Train epoch: 19 ]
# Train accuarcy: 71.48308505173553
# Train average loss: 0.024213393431569943
# [ Validation epoch: 20 ]
# Accuarcy: 80.39330789550925
# Average loss: 0.019048839094598938
# Model saved! (time elapsed: 309.6934196949005)
# [ Train epoch: 20 ]
# Train accuarcy: 72.10684670140162
# Train average loss: 0.023609105940740616
# [ Validation epoch: 21 ]
# Accuarcy: 79.48341649545054
# Average loss: 0.018938969587838857
# Model saved! (time elapsed: 324.4873597621918)
# [ Train epoch: 21 ]
# Train accuarcy: 72.12152344609966
# Train average loss: 0.023768385717924268
# [ Validation epoch: 22 ]
# Accuarcy: 78.28001174053419
# Average loss: 0.019163352125965327
# Model saved! (time elapsed: 339.3231363296509)
# [ Train epoch: 22 ]
# Train accuarcy: 72.4811036912013
# Train average loss: 0.02348020909213439
# [ Validation epoch: 23 ]
# Accuarcy: 78.86703845024948
# Average loss: 0.019311813470867325
# Model saved! (time elapsed: 355.2722501754761)
# [ Train epoch: 23 ]
# Train accuarcy: 72.12886181844867
# Train average loss: 0.023708606547932113
# [ Validation epoch: 24 ]
# Accuarcy: 75.81449955972997
# Average loss: 0.021765705398145853
# Model saved! (time elapsed: 370.0788106918335)
# [ Train epoch: 24 ]
# Train accuarcy: 73.1635723196595
# Train average loss: 0.02336058983530207
# [ Validation epoch: 25 ]
# Accuarcy: 77.51687701790432
# Average loss: 0.020331858084073753
# Model saved! (time elapsed: 384.69912457466125)
# [ Train epoch: 25 ]
# Train accuarcy: 72.75262346811478
# Train average loss: 0.023104142930998075
# [ Validation epoch: 26 ]
# Accuarcy: 78.48547108893455
# Average loss: 0.020100715317297863
# Model saved! (time elapsed: 403.6899108886719)
# [ Train epoch: 26 ]
# Train accuarcy: 73.41307697952594
# Train average loss: 0.022796640071041683
# [ Validation epoch: 27 ]
# Accuarcy: 76.69503962430291
# Average loss: 0.02032625066383794
# Model saved! (time elapsed: 422.4976933002472)
# [ Train epoch: 27 ]
# Train accuarcy: 73.53049093711014
# Train average loss: 0.02287255787111093
# [ Validation epoch: 28 ]
# Accuarcy: 78.95509245670678
# Average loss: 0.02056165725771269
# Model saved! (time elapsed: 437.3242516517639)
# [ Train epoch: 28 ]
# Train accuarcy: 73.96345490570191
# Train average loss: 0.022646165951739808
# [ Validation epoch: 29 ]
# Accuarcy: 79.36601115350749
# Average loss: 0.019508923428794105
# Model saved! (time elapsed: 451.99690866470337)
# [ Train epoch: 29 ]
# Train accuarcy: 74.22763631026638
# Train average loss: 0.02215193527945246
# [ Validation epoch: 30 ]
# Accuarcy: 80.42265923099501
# Average loss: 0.018917813927748703
# Model saved! (time elapsed: 466.84860587120056)

# %%
# 정확도(accuracy) 커브 시각화
plt.subplot(211)
plt.plot([i for i in range(epoch)], [i[0] for i in train_result])
plt.plot([i for i in range(epoch)], [i[0] for i in val_result])
plt.title("Accuracy Curve")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(["train", "val"])

# 손실(loss) 커브 시각화
plt.subplot(212)
plt.plot([i for i in range(epoch)], [i[1] for i in train_result])
plt.plot([i for i in range(epoch)], [i[1] for i in val_result])
plt.title("Loss Curve")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(["train", "val"])

plt.tight_layout()
plt.show()

# %% [markdown]
# #### <b>(알아보기) 혼동 행렬 시각화하기</b>
#
# * 참고: [Seaborn.heatmap 공식 문서](https://seaborn.pydata.org/generated/seaborn.heatmap.html)
# * 각 클래스에 대하여 정확히 분류하는지 확인하기 위해 <b>혼동 행렬(confusion matrix)</b>을 생성할 수 있습니다.

# %%
# 네트워크에 데이터셋을 입력하여 혼동 행렬(confusion matrix)을 계산하는 함수
def get_confusion_matrix(net, num_classes, data_loader):
    net.eval() # 모델을 평가 모드로 설정
    confusion_matrix = torch.zeros(num_classes, num_classes, dtype=torch.int32)

    for batch_idx, (inputs, targets) in enumerate(data_loader):
        inputs, targets = inputs.to(device), targets.to(device)

        outputs = net(inputs)
        _, predicted = outputs.max(1)

        for t, p in zip(targets.view(-1), predicted.view(-1)):
            confusion_matrix[t.long(), p.long()] += 1

    return confusion_matrix

# %%
import pandas as pd
import seaborn as sns


net = LeNet()
net = net.to(device)

file_name = "./checkpoint/LeNet.pt"
checkpoint = torch.load(file_name)
net.load_state_dict(checkpoint['net'])

# 평가 데이터셋을 이용해 혼동 행렬(confusion matrix) 계산하기
confusion_matrix = get_confusion_matrix(net, 6, val_dataloader)
print("[ 각 클래스당 데이터 개수 ]")
print(confusion_matrix.sum(1))

print("[ 혼동 행렬(confusion matrix) 시각화 ]")
res = pd.DataFrame(confusion_matrix.numpy(), index = [i for i in range(6)], columns = [i for i in range(6)])
res.index.name = 'True label'
res.columns.name = 'Predicted label'
plt.figure(figsize = (10, 7))
sns.heatmap(res, annot=True, fmt="d", cmap='Blues')
plt.show()

print("[ 각 클래스에 따른 정확도 ]")
# (각 클래스마다 정답 개수 / 각 클래스마다 데이터의 개수)
print(confusion_matrix.diag() / confusion_matrix.sum(1))

print("[ 전체 평균 정확도 ]")
print(confusion_matrix.diag().sum() / confusion_matrix.sum())
# Out:
# [ 각 클래스당 데이터 개수 ]
# tensor([523, 540, 594, 599, 560, 591])
# [ 혼동 행렬(confusion matrix) 시각화 ]
# [ 각 클래스에 따른 정확도 ]
# tensor([0.7036, 0.9426, 0.7155, 0.7629, 0.8607, 0.8443])
# [ 전체 평균 정확도 ]
# tensor(0.8042)

# %% [markdown]
# #### <b>Problem 3. CustomLeNet 아키텍처 작성하기</b>
#
# * 다음과 같이 LeNet 아키텍처를 변경하여 CustomLeNet을 만들어 봅시다.
#     * 커널 크기와 커널의 개수를 증가시켰습니다. (파라미터 수 증가)
#     * Fully Connected 레이어의 차원을 증가시켰습니다. (파라미터 수 증가)
#
# Layer | Type | Specification
# :-: | :-: | ---
# 1 | Input | image size: 3 X 64 X 64
# 2 | Convolution | # of kernel: 128, kernel size: 8 X 8, stride: 1, zero padding: 0
# 3 | Pooling | max pooling, kernel size: 2 X 2, stride: 2
# 4 | Convolution | # of kernel: 256, kernel size: 8 X 8, stride: 1, zero padding: 0
# 5 | Pooling | max pooling, kernel size: 2 X 2, stride: 2
# 6 | Convolution | # of kernel: 512, kernel size: 4 X 4, stride: 1, zero padding: 0
# 7 | Pooling | max pooling, kernel size: 2 X 2, stride: 2
# 8 | Fully Connected | # of neuron: 4096
# 9 | Activation | ReLU
# 10 | Fully Connected | # of neuron: 6
# 11 | Softmax | 6 classes

# %%
class CustomLeNet(nn.Module):
    def __init__(self):
        super(CustomLeNet, self).__init__()
        # 이 부분에 소스코드를 작성하세요.
        # image size: 3 X 64 X 64
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=128, kernel_size=8, stride=1, padding=0)
        # 128 X 57 X 57
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)
        # 128 X 28 X 28
        self.conv2 = nn.Conv2d(in_channels=128, out_channels=256, kernel_size=8, stride=1, padding=0)
        # 256 X 21 X 21
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)
        # 256 X 10 X 10
        self.conv3 = nn.Conv2d(in_channels=256, out_channels=512, kernel_size=4, stride=1, padding=0)
        # 512 X 7 X 7
        self.pool3 = nn.MaxPool2d(kernel_size=2, stride=2)
        # 512 X 3 X 3

        self.fc1 = nn.Linear(512 * 3 * 3, 4096)
        self.fc2 = nn.Linear(4096, 6)

    def forward(self, x):
        # 이 부분에 소스코드를 작성하세요.
        x = self.pool1(self.conv1(x))
        x = self.pool2(self.conv2(x))
        x = self.pool3(self.conv3(x))
        x = torch.flatten(x, 1)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %% [markdown]
# #### <b>(알아보기) CustomLeNet 평가하기</b>
#
# * 새롭게 작성한 CustomLeNet과 앞선 LeNet의 성능을 비교합니다.
#     * 파라미터가 증가한 만큼 성능 향상이 있는지 확인해 봅시다.
# * 아래 코드를 실행하여 학습 및 성능 평가를 진행할 수 있습니다.

# %%
import time
import torch.optim as optim


net = CustomLeNet()
net = net.to(device)

epoch = 30
learning_rate = 0.002
file_name = "CustomLeNet.pt"

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)

train_result = []
val_result = []

start_time = time.time() # 시작 시간

for i in range(epoch):
    train_acc, train_loss = train(net, i, optimizer, criterion, train_dataloader) # 학습(training)
    val_acc, val_loss = validate(net, i + 1, val_dataloader) # 검증(validation)

    # 학습된 모델 저장하기
    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print(f'Model saved! (time elapsed: {time.time() - start_time})')

    # 현재 epoch에서의 정확도(accuracy)와 손실(loss) 값 저장하기
    train_result.append((train_acc, train_loss))
    val_result.append((val_acc, val_loss))
# Out:
# [ Train epoch: 0 ]
# Train accuarcy: 47.50128421516108
# Train average loss: 0.04137394240520632
# [ Validation epoch: 1 ]
# Accuarcy: 56.589374816554155
# Average loss: 0.034861899923291556
# Model saved! (time elapsed: 24.82348370552063)
# [ Train epoch: 1 ]
# Train accuarcy: 56.189917076392454
# Train average loss: 0.03512458542503054
# [ Validation epoch: 2 ]
# Accuarcy: 64.86645142353977
# Average loss: 0.029225945175306377
# Model saved! (time elapsed: 51.01400685310364)
# [ Train epoch: 2 ]
# Train accuarcy: 59.06655903720555
# Train average loss: 0.03302264621219816
# [ Validation epoch: 3 ]
# Accuarcy: 69.06369239800411
# Average loss: 0.026580452700321857
# Model saved! (time elapsed: 75.57923293113708)
# [ Train epoch: 3 ]
# Train accuarcy: 60.31408233653776
# Train average loss: 0.032305440554013826
# [ Validation epoch: 4 ]
# Accuarcy: 68.94628705606105
# Average loss: 0.026202293454568547
# Model saved! (time elapsed: 100.91803860664368)
# [ Train epoch: 4 ]
# Train accuarcy: 61.56160563586997
# Train average loss: 0.03137925037365277
# [ Validation epoch: 5 ]
# Accuarcy: 72.26298796595245
# Average loss: 0.02455867015619169
# Model saved! (time elapsed: 125.73107862472534)
# [ Train epoch: 5 ]
# Train accuarcy: 63.095325456813676
# Train average loss: 0.030411580395014452
# [ Validation epoch: 6 ]
# Accuarcy: 69.76812444966247
# Average loss: 0.025893802031555377
# Model saved! (time elapsed: 150.6380956172943)
# [ Train epoch: 6 ]
# Train accuarcy: 63.85851618111103
# Train average loss: 0.02986449102509649
# [ Validation epoch: 7 ]
# Accuarcy: 72.14558262400939
# Average loss: 0.025026359584697504
# Model saved! (time elapsed: 175.71491527557373)
# [ Train epoch: 7 ]
# Train accuarcy: 64.45292434138108
# Train average loss: 0.029575496054696452
# [ Validation epoch: 8 ]
# Accuarcy: 72.9674200176108
# Average loss: 0.024196894402583744
# Model saved! (time elapsed: 201.05405187606812)
# [ Train epoch: 8 ]
# Train accuarcy: 65.58303368312909
# Train average loss: 0.028824343967920635
# [ Validation epoch: 9 ]
# Accuarcy: 70.2377458174347
# Average loss: 0.02509286733782113
# Model saved! (time elapsed: 226.7462830543518)
# [ Train epoch: 9 ]
# Train accuarcy: 65.20877669332943
# Train average loss: 0.0288693766395528
# [ Validation epoch: 10 ]
# Accuarcy: 73.5544467273261
# Average loss: 0.023532251922273203
# Model saved! (time elapsed: 252.10115599632263)
# [ Train epoch: 10 ]
# Train accuarcy: 65.73713950245835
# Train average loss: 0.028214836843192048
# [ Validation epoch: 11 ]
# Accuarcy: 74.66979747578515
# Average loss: 0.022443479331035854
# Model saved! (time elapsed: 276.7318162918091)
# [ Train epoch: 11 ]
# Train accuarcy: 67.24884420635503
# Train average loss: 0.0276371358889096
# [ Validation epoch: 12 ]
# Accuarcy: 75.13941884355738
# Average loss: 0.02225061976860652
# Model saved! (time elapsed: 301.20679330825806)
# [ Train epoch: 12 ]
# Train accuarcy: 66.88926396125339
# Train average loss: 0.027866507677476598
# [ Validation epoch: 13 ]
# Accuarcy: 75.05136483710008
# Average loss: 0.022102002606631234
# Model saved! (time elapsed: 325.8550443649292)
# [ Train epoch: 13 ]
# Train accuarcy: 67.01401629118662
# Train average loss: 0.02752789894806855
# [ Validation epoch: 14 ]
# Accuarcy: 74.75785148224244
# Average loss: 0.022784203229707672
# Model saved! (time elapsed: 350.435711145401)
# [ Train epoch: 14 ]
# Train accuarcy: 67.44698025977839
# Train average loss: 0.027119300351363684
# [ Validation epoch: 15 ]
# Accuarcy: 75.16877017904315
# Average loss: 0.022610315058565155
# Model saved! (time elapsed: 375.14178133010864)
# [ Train epoch: 15 ]
# Train accuarcy: 68.50370587803626
# Train average loss: 0.02690741716568806
# [ Validation epoch: 16 ]
# Accuarcy: 75.43293219841503
# Average loss: 0.02207385862122052
# Model saved! (time elapsed: 399.7103748321533)
# [ Train epoch: 16 ]
# Train accuarcy: 68.43032215454612
# Train average loss: 0.02662366865280833
# [ Validation epoch: 17 ]
# Accuarcy: 71.67596125623716
# Average loss: 0.0248415207789376
# Model saved! (time elapsed: 424.55761671066284)
# [ Train epoch: 17 ]
# Train accuarcy: 68.60644309092244
# Train average loss: 0.02677293514491545
# [ Validation epoch: 18 ]
# Accuarcy: 70.53125917229234
# Average loss: 0.024924242569968467
# Model saved! (time elapsed: 449.8062036037445)
# [ Train epoch: 18 ]
# Train accuarcy: 68.65781169736553
# Train average loss: 0.026307810684323633
# [ Validation epoch: 19 ]
# Accuarcy: 75.55033754035809
# Average loss: 0.022268976507769114
# Model saved! (time elapsed: 475.3777313232422)
# [ Train epoch: 19 ]
# Train accuarcy: 68.86328612313788
# Train average loss: 0.02602377241291338
# [ Validation epoch: 20 ]
# Accuarcy: 76.81244496624596
# Average loss: 0.021497335686234388
# Model saved! (time elapsed: 501.3808352947235)
# [ Train epoch: 20 ]
# Train accuarcy: 69.1494826447494
# Train average loss: 0.026188801822881403
# [ Validation epoch: 21 ]
# Accuarcy: 71.29439389492222
# Average loss: 0.025002921199672623
# Model saved! (time elapsed: 527.4599163532257)
# [ Train epoch: 21 ]
# Train accuarcy: 69.64115359213326
# Train average loss: 0.025627245746950432
# [ Validation epoch: 22 ]
# Accuarcy: 74.49368946287056
# Average loss: 0.022461384071224694
# Model saved! (time elapsed: 553.5023720264435)
# [ Train epoch: 22 ]
# Train accuarcy: 69.6118001027372
# Train average loss: 0.02556628209921552
# [ Validation epoch: 23 ]
# Accuarcy: 76.60698561784561
# Average loss: 0.02103916725560931
# Model saved! (time elapsed: 579.5913650989532)
# [ Train epoch: 23 ]
# Train accuarcy: 70.47038966757174
# Train average loss: 0.025052251399914953
# [ Validation epoch: 24 ]
# Accuarcy: 75.66774288230114
# Average loss: 0.02173935338343068
# Model saved! (time elapsed: 605.6439397335052)
# [ Train epoch: 24 ]
# Train accuarcy: 70.1695164012622
# Train average loss: 0.025240818120732193
# [ Validation epoch: 25 ]
# Accuarcy: 75.8732022307015
# Average loss: 0.022460537316129466
# Model saved! (time elapsed: 631.3312544822693)
# [ Train epoch: 25 ]
# Train accuarcy: 70.63917223159903
# Train average loss: 0.02510425255305088
# [ Validation epoch: 26 ]
# Accuarcy: 75.57968887584386
# Average loss: 0.022601438252709636
# Model saved! (time elapsed: 656.5995757579803)
# [ Train epoch: 26 ]
# Train accuarcy: 70.76392456153225
# Train average loss: 0.024853212096646166
# [ Validation epoch: 27 ]
# Accuarcy: 76.54828294687408
# Average loss: 0.021092603996173007
# Model saved! (time elapsed: 681.9185311794281)
# [ Train epoch: 27 ]
# Train accuarcy: 71.03544433844573
# Train average loss: 0.02467370636658946
# [ Validation epoch: 28 ]
# Accuarcy: 77.07660698561784
# Average loss: 0.02090321611126462
# Model saved! (time elapsed: 706.9862020015717)
# [ Train epoch: 28 ]
# Train accuarcy: 71.19688853012401
# Train average loss: 0.02456445690076857
# [ Validation epoch: 29 ]
# Accuarcy: 74.66979747578515
# Average loss: 0.02257987676668909
# Model saved! (time elapsed: 732.1384017467499)
# [ Train epoch: 29 ]
# Train accuarcy: 70.71989432743817
# Train average loss: 0.024593232625332286
# [ Validation epoch: 30 ]
# Accuarcy: 76.13736425007338
# Average loss: 0.020857428354988848
# Model saved! (time elapsed: 757.4019074440002)

# %%
# 정확도(accuracy) 커브 시각화
plt.subplot(211)
plt.plot([i for i in range(epoch)], [i[0] for i in train_result])
plt.plot([i for i in range(epoch)], [i[0] for i in val_result])
plt.title("Accuracy Curve")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(["train", "val"])

# 손실(loss) 커브 시각화
plt.subplot(212)
plt.plot([i for i in range(epoch)], [i[1] for i in train_result])
plt.plot([i for i in range(epoch)], [i[1] for i in val_result])
plt.title("Loss Curve")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(["train", "val"])

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns


net = CustomLeNet()
net = net.to(device)

file_name = "./checkpoint/CustomLeNet.pt"
checkpoint = torch.load(file_name)
net.load_state_dict(checkpoint['net'])

# 평가 데이터셋을 이용해 혼동 행렬(confusion matrix) 계산하기
confusion_matrix = get_confusion_matrix(net, 6, val_dataloader)
print("[ 각 클래스당 데이터 개수 ]")
print(confusion_matrix.sum(1))

print("[ 혼동 행렬(confusion matrix) 시각화 ]")
res = pd.DataFrame(confusion_matrix.numpy(), index = [i for i in range(6)], columns = [i for i in range(6)])
res.index.name = 'True label'
res.columns.name = 'Predicted label'
plt.figure(figsize = (10, 7))
sns.heatmap(res, annot=True, fmt="d", cmap='Blues')
plt.show()

print("[ 각 클래스에 따른 정확도 ]")
# (각 클래스마다 정답 개수 / 각 클래스마다 데이터의 개수)
print(confusion_matrix.diag() / confusion_matrix.sum(1))

print("[ 전체 평균 정확도 ]")
print(confusion_matrix.diag().sum() / confusion_matrix.sum())
# Out:
# [ 각 클래스당 데이터 개수 ]
# tensor([523, 540, 594, 599, 560, 591])
# [ 혼동 행렬(confusion matrix) 시각화 ]
# [ 각 클래스에 따른 정확도 ]
# tensor([0.7495, 0.9204, 0.7862, 0.6060, 0.7250, 0.7936])
# [ 전체 평균 정확도 ]
# tensor(0.7614)

# %% [markdown]
# #### <b>Problem 4. AlexNet 아키텍처 작성하기</b>
#
# * AlexNet은 CNN 기반의 분류 모델의 우수성을 전 세계에 알린 논문([NIPS 2012](https://papers.nips.cc/paper/2012/file/c399862d3b9d6b76c8436e924a68c45b-Paper.pdf))입니다.
#     * ImageNet 분류 대회(ILSVRC 2012)에서 압도적인 성능으로 우승(1위)을 차지했습니다.
#
# <hr>
#
# * LRN (Local Response Normalization)을 활용합니다.
#     * PyTorch에서 [nn.LocalResponseNorm()](https://pytorch.org/docs/stable/generated/torch.nn.LocalResponseNorm.html)을 이용해 구현할 수 있습니다.
#     * Local Response Normalization은 입력과 출력의 차원이 동일한 레이어입니다.
# * Dropout을 활용합니다.
#     * PyTorch에서 [nn.Dropout()](https://pytorch.org/docs/stable/generated/torch.nn.Dropout.html)을 이용해 구현할 수 있습니다.
# * ReLU를 적극적으로 활용합니다.
#     * PyTorch에서 [nn.ReLU()](https://pytorch.org/docs/stable/generated/torch.nn.ReLU.html)를 이용해 구현할 수 있습니다.
#
# <hr>
#
# * <b>아래의 표</b>와 같은 아키텍처를 PyTorch로 구현해 봅시다.
#     * 원본 논문에서 제안한 것과 완전히 동일한 아키텍처는 아니지만, 핵심 아이디어를 잘 포함하고 있습니다.
#
# Layer | Type | Specification
# :-: | :-: | ---
# 1 | Input | image size: 3 X 64 X 64
# 2 | Convolution | # of kernel: 96, kernel size: 5 X 5, stride: 1, zero padding: 2
# 3 | Activation | ReLU
# 4 | Normalization | LRN (Local Response Normalization), size: 5
# 5 | Pooling | max pooling, kernel size: 3 X 3, stride: 2
# 6 | Convolution | # of kernel: 256, kernel size: 5 X 5, stride: 1, zero padding: 2
# 7 | Activation | ReLU
# 8 | Normalization | LRN (Local Response Normalization), size: 5
# 9 | Pooling | max pooling, kernel size: 3 X 3, stride: 2
# 10 | Convolution | # of kernel: 384, kernel size: 3 X 3, stride: 1, zero padding: 1
# 11 | Activation | ReLU
# 12 | Convolution | # of kernel: 384, kernel size: 3 X 3, stride: 1, zero padding: 1
# 13 | Activation | ReLU
# 14 | Convolution | # of kernel: 256, kernel size: 3 X 3, stride: 1, zero padding: 1
# 15 | Activation | ReLU
# 16 | Pooling | max pooling, kernel size: 3 X 3, stride: 2
# 17 | Fully Connected | # of neuron: 4096
# 18 | Activation | ReLU
# 19 | Dropout | Probability: 0.5
# 20 | Fully Connected | # of neuron: 6
# 21 | Dropout | Probability: 0.5
# 22 | Softmax | 6 classes
#
# * 표와 동일하게 정상적으로 구현했다면, <b>83~85%가량의 정확도</b>를 얻을 수 있습니다.

# %%
class AlexNet(nn.Module):
    def __init__(self):
        super(AlexNet, self).__init__()
        # 이 부분에 소스코드를 작성하세요.
        self.features=nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=96, kernel_size=5, stride=1, padding=2),
            nn.ReLU(inplace=True),
            nn.LocalResponseNorm(size=5),
            nn.MaxPool2d(kernel_size=3, stride=2),

            nn.Conv2d(in_channels=96, out_channels=256, kernel_size=5, stride=1, padding=2),
            nn.ReLU(inplace=True),
            nn.LocalResponseNorm(size=5),
            nn.MaxPool2d(kernel_size=3, stride=2),

            nn.Conv2d(in_channels=256, out_channels=384, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),

            nn.Conv2d(in_channels=384, out_channels=384, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),

            nn.Conv2d(in_channels=384, out_channels=256, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2)

        )

        self.classifier=nn.Sequential(
        nn.Linear(256 * 7 * 7, 4096),
        nn.ReLU(inplace=True),
        nn.Dropout(),
        nn.Linear(4096, 6),
        nn.Dropout()
        )

    def forward(self, x):
        # 이 부분에 소스코드를 작성하세요.
        x=self.features(x)
        x=torch.flatten(x,1)
        x=self.classifier(x)
        return x

# %% [markdown]
# #### <b>(알아보기) AlexNet 평가하기</b>
#
# * 아래 코드를 실행하여 학습 및 성능 평가를 진행할 수 있습니다.
# * 83~85%가량의 정확도가 나오지 않는다면, 표와 동일하게 AlexNet 코드를 다시 작성했는지 확인해 주세요.

# %%
import time
import torch.optim as optim

net = AlexNet()
net = net.to(device)

epoch = 30
learning_rate = 0.002
file_name = "AlexNet.pt"

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)

train_result = []
val_result = []

start_time = time.time() # 시작 시간

for i in range(epoch):
    train_acc, train_loss = train(net, i, optimizer, criterion, train_dataloader) # 학습(training)
    val_acc, val_loss = validate(net, i + 1, val_dataloader) # 검증(validation)

    # 학습된 모델 저장하기
    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print(f'Model saved! (time elapsed: {time.time() - start_time})')

    # 현재 epoch에서의 정확도(accuracy)와 손실(loss) 값 저장하기
    train_result.append((train_acc, train_loss))
    val_result.append((val_acc, val_loss))
# Out:
# [ Train epoch: 0 ]
# Train accuarcy: 30.98994642988185
# Train average loss: 0.050625288653567926
# [ Validation epoch: 1 ]
# Accuarcy: 49.16348693865571
# Average loss: 0.04213353444797257
# Model saved! (time elapsed: 3791.025742292404)
# [ Train epoch: 1 ]
# Train accuarcy: 39.502458354736916
# Train average loss: 0.04557954672804108
# [ Validation epoch: 2 ]

# %%
# 정확도(accuracy) 커브 시각화
plt.subplot(211)
plt.plot([i for i in range(epoch)], [i[0] for i in train_result])
plt.plot([i for i in range(epoch)], [i[0] for i in val_result])
plt.title("Accuracy Curve")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(["train", "val"])

# 손실(loss) 커브 시각화
plt.subplot(212)
plt.plot([i for i in range(epoch)], [i[1] for i in train_result])
plt.plot([i for i in range(epoch)], [i[1] for i in val_result])
plt.title("Loss Curve")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(["train", "val"])

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns


net = AlexNet()
net = net.to(device)

file_name = "./checkpoint/AlexNet.pt"
checkpoint = torch.load(file_name)
net.load_state_dict(checkpoint['net'])

# 평가 데이터셋을 이용해 혼동 행렬(confusion matrix) 계산하기
confusion_matrix = get_confusion_matrix(net, 6, val_dataloader)
print("[ 각 클래스당 데이터 개수 ]")
print(confusion_matrix.sum(1))

print("[ 혼동 행렬(confusion matrix) 시각화 ]")
res = pd.DataFrame(confusion_matrix.numpy(), index = [i for i in range(6)], columns = [i for i in range(6)])
res.index.name = 'True label'
res.columns.name = 'Predicted label'
plt.figure(figsize = (10, 7))
sns.heatmap(res, annot=True, fmt="d", cmap='Blues')
plt.show()

print("[ 각 클래스에 따른 정확도 ]")
# (각 클래스마다 정답 개수 / 각 클래스마다 데이터의 개수)
print(confusion_matrix.diag() / confusion_matrix.sum(1))

print("[ 전체 평균 정확도 ]")
print(confusion_matrix.diag().sum() / confusion_matrix.sum())

# %% [markdown]
# #### <b>(알아보기) LightResNet 아키텍처 살펴보기</b>
#
# * [ResNet (2016 CVPR)](https://arxiv.org/abs/1512.03385) 논문에서 제안된 가벼운 ResNet을 PyTorch로 구현한 것은 다음과 같습니다.
#     * 원본 논문에서는 CIFAR-10을 위하여 해당 아키텍처를 제안했습니다.
# * 레이어의 깊이에 따라 다양한 버전이 있습니다.
#     * 다양한 버전: 20 레이어, 32 레이어, 44 레이어, 56 레이어, 110 레이어
#     * 일반적으로 더 깊은 레이어로 구성된 ResNet이 더 높은 정확도를 보입니다.

# %%
# ResNet을 위한 BasicBlock 클래스 정의
class BasicBlock(nn.Module):
    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()

        # 3x3 필터를 사용 (stride 값이 2라면, 너비와 높이가 절반으로 감소)
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes) # 배치 정규화(batch normalization)

        # 3x3 필터를 사용 (stride 값이 1이므로, 너비와 높이가 유지)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes) # 배치 정규화(batch normalization)

        self.shortcut = nn.Sequential() # identity인 경우
        if stride != 1: # stride가 1이 아니라면, identity mapping이 아닌 경우
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, planes, kernel_size=1, stride=stride, padding=0, bias=False),
                nn.BatchNorm2d(planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x) # (핵심) skip connection
        out = F.relu(out)
        return out


# LightResNet 클래스 정의
class LightResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=6):
        super(LightResNet, self).__init__()
        self.in_planes = 16

        # 16개의 3x3 필터(filter)를 사용
        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(16)
        # 첫 레이어를 제외하고는 너비와 높이를 줄이기 위해 stride를 2로 설정
        self.layer1 = self._make_layer(block, 16, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 32, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 64, num_blocks[2], stride=2)
        self.linear = nn.Linear(64, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1) # 첫째 블록만 너비와 높이 감소
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes # 다음 레이어를 위해 채널 수 변경
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = F.avg_pool2d(out, out.size()[3])
        out = out.view(out.size(0), -1) # 배치(batch)를 제외한 모든 차원 flatten하기
        out = self.linear(out)
        return out


def LightResNet20():
    return LightResNet(BasicBlock, [3, 3, 3])


def LightResNet32():
    return LightResNet(BasicBlock, [5, 5, 5])


def LightResNet44():
    return LightResNet(BasicBlock, [7, 7, 7])


def LightResNet56():
    return LightResNet(BasicBlock, [9, 9, 9])


def LightResNet110():
    return LightResNet(BasicBlock, [18, 18, 18])

# %% [markdown]
# #### <b>(알아보기) LightResNet-20 학습하기</b>
#
# * PyTorch로 구현된 LightResNet-20 모델을 학습해 봅시다.

# %%
import time
import torch.optim as optim


net = LightResNet20()
net = net.to(device)

epoch = 30
learning_rate = 0.002
file_name = "LightResNet20.pt"

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)

train_result = []
val_result = []

start_time = time.time() # 시작 시간

for i in range(epoch):
    train_acc, train_loss = train(net, i, optimizer, criterion, train_dataloader) # 학습(training)
    val_acc, val_loss = validate(net, i + 1, val_dataloader) # 검증(validation)

    # 학습된 모델 저장하기
    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print(f'Model saved! (time elapsed: {time.time() - start_time})')

    # 현재 epoch에서의 정확도(accuracy)와 손실(loss) 값 저장하기
    train_result.append((train_acc, train_loss))
    val_result.append((val_acc, val_loss))
# Out:
# [ Train epoch: 0 ]
# Train accuarcy: 52.57209950832905
# Train average loss: 0.03660029345670764
# [ Validation epoch: 1 ]
# Accuarcy: 62.25418256530672
# Average loss: 0.029277982339503517
# Model saved! (time elapsed: 443.0548503398895)
# [ Train epoch: 1 ]
# Train accuarcy: 64.71710574594555
# Train average loss: 0.028829988917505225
# [ Validation epoch: 2 ]
# Accuarcy: 65.10126210742588
# Average loss: 0.02702576245665375
# Model saved! (time elapsed: 864.7356748580933)
# [ Train epoch: 2 ]
# Train accuarcy: 69.36963381521979
# Train average loss: 0.025394985670038072
# [ Validation epoch: 3 ]
# Accuarcy: 73.84796008218373
# Average loss: 0.023596562394866294
# Model saved! (time elapsed: 1297.0954763889313)
# [ Train epoch: 3 ]
# Train accuarcy: 71.83532692448814
# Train average loss: 0.02348015795338746
# [ Validation epoch: 4 ]
# Accuarcy: 76.90049897270326
# Average loss: 0.019512158012963965
# Model saved! (time elapsed: 1710.3215465545654)
# [ Train epoch: 4 ]
# Train accuarcy: 73.87539443751376
# Train average loss: 0.022046629546401943
# [ Validation epoch: 5 ]
# Accuarcy: 79.89433519225125
# Average loss: 0.018185116562774745
# Model saved! (time elapsed: 2136.4600088596344)
# [ Train epoch: 5 ]
# Train accuarcy: 74.8073677258384
# Train average loss: 0.021429481995886943
# [ Validation epoch: 6 ]
# Accuarcy: 78.30936307601996
# Average loss: 0.01913513701123718
# Model saved! (time elapsed: 2568.116783618927)
# [ Train epoch: 6 ]
# Train accuarcy: 75.90812357819036
# Train average loss: 0.02062569136419063
# [ Validation epoch: 7 ]
# Accuarcy: 79.6008218373936
# Average loss: 0.01767078949570971
# Model saved! (time elapsed: 3000.253169298172)
# [ Train epoch: 7 ]
# Train accuarcy: 76.58325383429955
# Train average loss: 0.02010065102827403
# [ Validation epoch: 8 ]
# Accuarcy: 81.36190196653948
# Average loss: 0.01585200999729228
# Model saved! (time elapsed: 3423.5446898937225)
# [ Train epoch: 8 ]
# Train accuarcy: 77.49321200557716
# Train average loss: 0.019138582919588212
# [ Validation epoch: 9 ]
# Accuarcy: 79.65952450836512
# Average loss: 0.016916355561538286
# Model saved! (time elapsed: 3846.8622102737427)
# [ Train epoch: 9 ]
# Train accuarcy: 77.48587363322815
# Train average loss: 0.019208762894515168
# [ Validation epoch: 10 ]
# Accuarcy: 81.80217199882594
# Average loss: 0.01575143109118095
# Model saved! (time elapsed: 4274.999145269394)
# [ Train epoch: 10 ]
# Train accuarcy: 77.9114992294709
# Train average loss: 0.018803415834628155
# [ Validation epoch: 11 ]
# Accuarcy: 84.29703551511594
# Average loss: 0.014260113602304584
# Model saved! (time elapsed: 4700.848854780197)
# [ Train epoch: 11 ]
# Train accuarcy: 77.88948411242386
# Train average loss: 0.018546500432217488
# [ Validation epoch: 12 ]
# Accuarcy: 81.5086586439683
# Average loss: 0.015186226198251275
# Model saved! (time elapsed: 5128.291811466217)
# [ Train epoch: 12 ]
# Train accuarcy: 78.6379980920232
# Train average loss: 0.018215900621507262
# [ Validation epoch: 13 ]
# Accuarcy: 84.41444085705899
# Average loss: 0.013880803140160762
# Model saved! (time elapsed: 5553.238529205322)
# [ Train epoch: 13 ]
# Train accuarcy: 79.07096206061496
# Train average loss: 0.01785804667664071
# [ Validation epoch: 14 ]
# Accuarcy: 84.85471088934547
# Average loss: 0.013797560451420514
# Model saved! (time elapsed: 5980.6152601242065)
# [ Train epoch: 14 ]
# Train accuarcy: 79.37183532692448
# Train average loss: 0.01760785233544054
# [ Validation epoch: 15 ]
# Accuarcy: 83.06427942471383
# Average loss: 0.01427731247269446
# Model saved! (time elapsed: 6406.060847997665)
# [ Train epoch: 15 ]
# Train accuarcy: 79.67270859323402
# Train average loss: 0.01708942197616989
# [ Validation epoch: 16 ]
# Accuarcy: 84.53184619900206
# Average loss: 0.013741327711554053
# Model saved! (time elapsed: 6837.310853481293)
# [ Train epoch: 16 ]
# Train accuarcy: 79.76076906142218
# Train average loss: 0.017144236772970365
# [ Validation epoch: 17 ]
# Accuarcy: 85.70589961843264
# Average loss: 0.013002553721274804
# Model saved! (time elapsed: 7269.509846448898)
# [ Train epoch: 17 ]
# Train accuarcy: 80.4505760622294
# Train average loss: 0.016924751313817276
# [ Validation epoch: 18 ]
# Accuarcy: 84.61990020545934
# Average loss: 0.013661542267158369
# Model saved! (time elapsed: 7694.680916786194)
# [ Train epoch: 18 ]
# Train accuarcy: 80.0029353489396
# Train average loss: 0.017094602324891406
# [ Validation epoch: 19 ]
# Accuarcy: 84.94276489580275
# Average loss: 0.013747411024231066
# Model saved! (time elapsed: 8124.008465051651)
# [ Train epoch: 19 ]
# Train accuarcy: 80.1203493065238
# Train average loss: 0.016699424606037218
# [ Validation epoch: 20 ]
# Accuarcy: 84.64925154094512
# Average loss: 0.013503458349803413
# Model saved! (time elapsed: 8559.560517549515)
# [ Train epoch: 20 ]
# Train accuarcy: 80.71475746679387
# Train average loss: 0.016676887468519412
# [ Validation epoch: 21 ]
# Accuarcy: 84.15027883768711
# Average loss: 0.014518763155995977
# Model saved! (time elapsed: 9007.591515302658)
# [ Train epoch: 21 ]
# Train accuarcy: 81.14772143538563
# Train average loss: 0.016165824579267025
# [ Validation epoch: 22 ]
# Accuarcy: 86.02876430877605
# Average loss: 0.01289838061965663
# Model saved! (time elapsed: 9431.263698339462)
# [ Train epoch: 22 ]
# Train accuarcy: 81.55867028693037
# Train average loss: 0.015995528192200664
# [ Validation epoch: 23 ]
# Accuarcy: 84.97211623128852
# Average loss: 0.01314244253573475
# Model saved! (time elapsed: 9857.850847482681)
# [ Train epoch: 23 ]
# Train accuarcy: 81.63205401042049
# Train average loss: 0.015741210135341417
# [ Validation epoch: 24 ]
# Accuarcy: 85.17757557968888
# Average loss: 0.013264312771607396
# Model saved! (time elapsed: 10283.79560637474)
# [ Train epoch: 24 ]
# Train accuarcy: 81.65406912746752
# Train average loss: 0.01569979848743246
# [ Validation epoch: 25 ]
# Accuarcy: 86.05811564426182
# Average loss: 0.012649933784316633
# Model saved! (time elapsed: 10718.245591878891)
# [ Train epoch: 25 ]
# Train accuarcy: 82.17509356424745
# Train average loss: 0.015288069883612008
# [ Validation epoch: 26 ]
# Accuarcy: 85.03081890226005
# Average loss: 0.013010569865888328
# Model saved! (time elapsed: 11165.38202381134)
# [ Train epoch: 26 ]
# Train accuarcy: 81.94760402142805
# Train average loss: 0.01569750141881397
# [ Validation epoch: 27 ]
# Accuarcy: 83.62195479894335
# Average loss: 0.014397168241710232
# Model saved! (time elapsed: 11660.923846006393)
# [ Train epoch: 27 ]
# Train accuarcy: 82.10170984075732
# Train average loss: 0.01536701149965685
# [ Validation epoch: 28 ]
# Accuarcy: 86.58643968300558
# Average loss: 0.012090979946002535
# Model saved! (time elapsed: 12082.615353345871)
# [ Train epoch: 28 ]
# Train accuarcy: 81.98429588317312
# Train average loss: 0.01539044674515173
# [ Validation epoch: 29 ]
# Accuarcy: 85.76460228940417
# Average loss: 0.012628137866335248
# Model saved! (time elapsed: 12503.326894760132)
# [ Train epoch: 29 ]
# Train accuarcy: 81.96228076612607
# Train average loss: 0.015421027713627829
# [ Validation epoch: 30 ]
# Accuarcy: 85.2362782506604
# Average loss: 0.012828005503481493
# Model saved! (time elapsed: 12932.452419281006)

# %%
# 정확도(accuracy) 커브 시각화
plt.subplot(211)
plt.plot([i for i in range(epoch)], [i[0] for i in train_result])
plt.plot([i for i in range(epoch)], [i[0] for i in val_result])
plt.title("Accuracy Curve")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(["train", "val"])

# 손실(loss) 커브 시각화
plt.subplot(212)
plt.plot([i for i in range(epoch)], [i[1] for i in train_result])
plt.plot([i for i in range(epoch)], [i[1] for i in val_result])
plt.title("Loss Curve")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(["train", "val"])

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns


net = LightResNet20()
net = net.to(device)

file_name = "./checkpoint/LightResNet20.pt"
checkpoint = torch.load(file_name)
net.load_state_dict(checkpoint['net'])

# 평가 데이터셋을 이용해 혼동 행렬(confusion matrix) 계산하기
confusion_matrix = get_confusion_matrix(net, 6, val_dataloader)
print("[ 각 클래스당 데이터 개수 ]")
print(confusion_matrix.sum(1))

print("[ 혼동 행렬(confusion matrix) 시각화 ]")
res = pd.DataFrame(confusion_matrix.numpy(), index = [i for i in range(6)], columns = [i for i in range(6)])
res.index.name = 'True label'
res.columns.name = 'Predicted label'
plt.figure(figsize = (10, 7))
sns.heatmap(res, annot=True, fmt="d", cmap='Blues')
plt.show()

print("[ 각 클래스에 따른 정확도 ]")
# (각 클래스마다 정답 개수 / 각 클래스마다 데이터의 개수)
print(confusion_matrix.diag() / confusion_matrix.sum(1))

print("[ 전체 평균 정확도 ]")
print(confusion_matrix.diag().sum() / confusion_matrix.sum())
# Out:
# [ 각 클래스당 데이터 개수 ]
# tensor([523, 540, 594, 599, 560, 591])
# [ 혼동 행렬(confusion matrix) 시각화 ]
# [ 각 클래스에 따른 정확도 ]
# tensor([0.8528, 0.9574, 0.7727, 0.8097, 0.9429, 0.8545])
# [ 전체 평균 정확도 ]
# tensor(0.8629)

# %% [markdown]
# #### <b>Problem 5. 다양한 레이어 깊이에 따라 LightResNet 학습하기</b>
#
# * Residual Block을 사용하는 경우 깊이가 깊어져도 좋은 성능을 내는 경향이 있습니다.
# * 다음의 LightResNet 모델들에 대하여 각각 학습을 진행한 뒤에, 검증 정확도(validation accuracy)를 쓰세요.
#     * LightResNet32: 85.29498092163193
#     * LightResNet56: 86.61579101849134
#     * LightResNet110: 84.88406222483123
# * 레이어가 깊어짐에 따라서 성능이 좋아지나요? 아니요
#     * 그 이유는: 레이어의 개수만 다른 다양한 LightResNet을 통해 실험한 결과, Layer가 깊어질 수록
# 성능이 높아지는 경향이 있는 것으로 확인했다.
# 그러나 지금 실험에 사용한 데이터에 한해서 들어간 학습시간도 성능의 일환으로 봤을 때, 늘어난 학습시간에 비해 유의미한 accuracy의 증가를 보지 못했기 때문에 데이터에 맞는 적절한 layer 깊이 설정이 필요하다고 본다.
# accuracy의 증가 경향의 이유에 대해서는 기존 깊은 layer를 가진 모델들이 gradient vanishing 문제로 학습이 어려웠던 것에 반해, Residual block의 skip connection을 통해 deep learning의 gradient flow를 원활하게 했기 때문이라고 생각한다.

# %%
import time
import torch.optim as optim


net = LightResNet32()
net = net.to(device)

epoch = 30
learning_rate = 0.002
file_name = "LightResNet32.pt"

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)

train_result = []
val_result = []

start_time = time.time() # 시작 시간

for i in range(epoch):
    train_acc, train_loss = train(net, i, optimizer, criterion, train_dataloader) # 학습(training)
    val_acc, val_loss = validate(net, i + 1, val_dataloader) # 검증(validation)

    # 학습된 모델 저장하기
    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print(f'Model saved! (time elapsed: {time.time() - start_time})')

    # 현재 epoch에서의 정확도(accuracy)와 손실(loss) 값 저장하기
    train_result.append((train_acc, train_loss))
    val_result.append((val_acc, val_loss))
# Out:
# [ Train epoch: 0 ]
# Train accuarcy: 51.76487854993763
# Train average loss: 0.037145357803981024
# [ Validation epoch: 1 ]
# Accuarcy: 58.61461696507191
# Average loss: 0.034223690773337194
# Model saved! (time elapsed: 42.005743741989136)
# [ Train epoch: 1 ]
# Train accuarcy: 63.96125339399721
# Train average loss: 0.029096268420874823
# [ Validation epoch: 2 ]
# Accuarcy: 73.6425007337834
# Average loss: 0.02256142735341304
# Model saved! (time elapsed: 65.86382007598877)
# [ Train epoch: 2 ]
# Train accuarcy: 68.57708960152638
# Train average loss: 0.026177049396130258
# [ Validation epoch: 3 ]
# Accuarcy: 71.85206926915174
# Average loss: 0.022907333925808144
# Model saved! (time elapsed: 90.02002882957458)
# [ Train epoch: 3 ]
# Train accuarcy: 71.13818155133191
# Train average loss: 0.023997124738036085
# [ Validation epoch: 4 ]
# Accuarcy: 78.10390372761961
# Average loss: 0.019053355305468474
# Model saved! (time elapsed: 114.45365977287292)
# [ Train epoch: 4 ]
# Train accuarcy: 72.66456299992662
# Train average loss: 0.02297119495672202
# [ Validation epoch: 5 ]
# Accuarcy: 77.6049310243616
# Average loss: 0.02051259984464844
# Model saved! (time elapsed: 138.5090651512146)
# [ Train epoch: 5 ]
# Train accuarcy: 74.014823512145
# Train average loss: 0.022335395266149454
# [ Validation epoch: 6 ]
# Accuarcy: 80.51071323745231
# Average loss: 0.01702959139237909
# Model saved! (time elapsed: 162.7235550880432)
# [ Train epoch: 6 ]
# Train accuarcy: 74.55052469362296
# Train average loss: 0.02155140888238676
# [ Validation epoch: 7 ]
# Accuarcy: 78.25066040504844
# Average loss: 0.019088313022876086
# Model saved! (time elapsed: 187.00346112251282)
# [ Train epoch: 7 ]
# Train accuarcy: 75.43112937550451
# Train average loss: 0.02100298218491965
# [ Validation epoch: 8 ]
# Accuarcy: 72.43909597886704
# Average loss: 0.024249591302899696
# Model saved! (time elapsed: 211.0473828315735)
# [ Train epoch: 8 ]
# Train accuarcy: 75.74667938651207
# Train average loss: 0.020641224551351332
# [ Validation epoch: 9 ]
# Accuarcy: 80.48136190196654
# Average loss: 0.01662630611215479
# Model saved! (time elapsed: 235.1979477405548)
# [ Train epoch: 9 ]
# Train accuarcy: 75.90812357819036
# Train average loss: 0.02002865038448571
# [ Validation epoch: 10 ]
# Accuarcy: 82.09568535368359
# Average loss: 0.016567447067776627
# Model saved! (time elapsed: 260.10199546813965)
# [ Train epoch: 10 ]
# Train accuarcy: 77.39047479269098
# Train average loss: 0.01933096336992119
# [ Validation epoch: 11 ]
# Accuarcy: 81.97828001174054
# Average loss: 0.015401405001582377
# Model saved! (time elapsed: 284.39199781417847)
# [ Train epoch: 11 ]
# Train accuarcy: 78.1316503999413
# Train average loss: 0.018591431128162538
# [ Validation epoch: 12 ]
# Accuarcy: 79.57147050190784
# Average loss: 0.01796476457662725
# Model saved! (time elapsed: 307.8965127468109)
# [ Train epoch: 12 ]
# Train accuarcy: 78.55727599618405
# Train average loss: 0.018348742922963596
# [ Validation epoch: 13 ]
# Accuarcy: 81.71411799236866
# Average loss: 0.017027627439452714
# Model saved! (time elapsed: 331.52275037765503)
# [ Train epoch: 13 ]
# Train accuarcy: 78.21237249578044
# Train average loss: 0.018562614377564797
# [ Validation epoch: 14 ]
# Accuarcy: 83.00557675374229
# Average loss: 0.015168100079378846
# Model saved! (time elapsed: 356.2048089504242)
# [ Train epoch: 14 ]
# Train accuarcy: 78.82879577309753
# Train average loss: 0.01796842118942651
# [ Validation epoch: 15 ]
# Accuarcy: 83.62195479894335
# Average loss: 0.014490137308057467
# Model saved! (time elapsed: 380.3414182662964)
# [ Train epoch: 15 ]
# Train accuarcy: 79.07096206061496
# Train average loss: 0.017797215187454238
# [ Validation epoch: 16 ]
# Accuarcy: 85.17757557968888
# Average loss: 0.013045043894752646
# Model saved! (time elapsed: 404.727557182312)
# [ Train epoch: 16 ]
# Train accuarcy: 79.49658765685771
# Train average loss: 0.017347127625639024
# [ Validation epoch: 17 ]
# Accuarcy: 82.15438802465512
# Average loss: 0.016184461717735753
# Model saved! (time elapsed: 428.6885681152344)
# [ Train epoch: 17 ]
# Train accuarcy: 79.658031848536
# Train average loss: 0.017624303845069095
# [ Validation epoch: 18 ]
# Accuarcy: 78.72028177282067
# Average loss: 0.018620700112073556
# Model saved! (time elapsed: 452.9389123916626)
# [ Train epoch: 18 ]
# Train accuarcy: 79.6066632420929
# Train average loss: 0.01726941123234077
# [ Validation epoch: 19 ]
# Accuarcy: 83.21103610214264
# Average loss: 0.014345482695931944
# Model saved! (time elapsed: 476.1571650505066)
# [ Train epoch: 19 ]
# Train accuarcy: 80.8468481690761
# Train average loss: 0.016511326598746677
# [ Validation epoch: 20 ]
# Accuarcy: 85.35368359260346
# Average loss: 0.013308632638855417
# Model saved! (time elapsed: 500.03679633140564)
# [ Train epoch: 20 ]
# Train accuarcy: 79.84149115726132
# Train average loss: 0.017113343466226637
# [ Validation epoch: 21 ]
# Accuarcy: 82.94687408277076
# Average loss: 0.01489045253143235
# Model saved! (time elapsed: 524.1234188079834)
# [ Train epoch: 21 ]
# Train accuarcy: 80.34050047699421
# Train average loss: 0.016701333211104622
# [ Validation epoch: 22 ]
# Accuarcy: 85.61784561197534
# Average loss: 0.012939343131074886
# Model saved! (time elapsed: 548.245395898819)
# [ Train epoch: 22 ]
# Train accuarcy: 81.19909004182873
# Train average loss: 0.01622010853846582
# [ Validation epoch: 23 ]
# Accuarcy: 86.17552098620487
# Average loss: 0.012671662082866662
# Model saved! (time elapsed: 572.2249426841736)
# [ Train epoch: 23 ]
# Train accuarcy: 81.28715051001687
# Train average loss: 0.01627011906399086
# [ Validation epoch: 24 ]
# Accuarcy: 85.35368359260346
# Average loss: 0.0134044311151219
# Model saved! (time elapsed: 596.4117434024811)
# [ Train epoch: 24 ]
# Train accuarcy: 80.795479562633
# Train average loss: 0.016280191627848373
# [ Validation epoch: 25 ]
# Accuarcy: 85.67654828294687
# Average loss: 0.012743984634728596
# Model saved! (time elapsed: 620.3945415019989)
# [ Train epoch: 25 ]
# Train accuarcy: 81.32384237176194
# Train average loss: 0.0157728967717277
# [ Validation epoch: 26 ]
# Accuarcy: 85.1482242442031
# Average loss: 0.013765894578529796
# Model saved! (time elapsed: 643.812141418457)
# [ Train epoch: 26 ]
# Train accuarcy: 81.65406912746752
# Train average loss: 0.015960753178346304
# [ Validation epoch: 27 ]
# Accuarcy: 81.77282066334018
# Average loss: 0.016371573352957178
# Model saved! (time elapsed: 667.9938175678253)
# [ Train epoch: 27 ]
# Train accuarcy: 81.34585748880899
# Train average loss: 0.015594889906905425
# [ Validation epoch: 28 ]
# Accuarcy: 86.43968300557675
# Average loss: 0.012105116376279909
# Model saved! (time elapsed: 692.022545337677)
# [ Train epoch: 28 ]
# Train accuarcy: 81.94026564907904
# Train average loss: 0.015460695986913254
# [ Validation epoch: 29 ]
# Accuarcy: 84.44379219254476
# Average loss: 0.013207556864086539
# Model saved! (time elapsed: 716.1204926967621)
# [ Train epoch: 29 ]
# Train accuarcy: 82.07235635136126
# Train average loss: 0.015386216123201898
# [ Validation epoch: 30 ]
# Accuarcy: 85.29498092163193
# Average loss: 0.013464957591565012
# Model saved! (time elapsed: 740.0691509246826)

# %%
import time
import torch.optim as optim


net = LightResNet56()
net = net.to(device)

epoch = 30
learning_rate = 0.002
file_name = "LightResNet56.pt"

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)

train_result = []
val_result = []

start_time = time.time() # 시작 시간

for i in range(epoch):
    train_acc, train_loss = train(net, i, optimizer, criterion, train_dataloader) # 학습(training)
    val_acc, val_loss = validate(net, i + 1, val_dataloader) # 검증(validation)

    # 학습된 모델 저장하기
    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print(f'Model saved! (time elapsed: {time.time() - start_time})')

    # 현재 epoch에서의 정확도(accuracy)와 손실(loss) 값 저장하기
    train_result.append((train_acc, train_loss))
    val_result.append((val_acc, val_loss))
# Out:
# [ Train epoch: 0 ]
# Train accuarcy: 49.48264474939459
# Train average loss: 0.038192148869793635
# [ Validation epoch: 1 ]
# Accuarcy: 65.15996477839742
# Average loss: 0.02820262128319389
# Model saved! (time elapsed: 42.45694875717163)
# [ Train epoch: 1 ]
# Train accuarcy: 62.07529170030087
# Train average loss: 0.03047758685945021
# [ Validation epoch: 2 ]
# Accuarcy: 56.94159084238333
# Average loss: 0.03703411984100767
# Model saved! (time elapsed: 77.6153085231781)
# [ Train epoch: 2 ]
# Train accuarcy: 66.50033022675571
# Train average loss: 0.027698925968800584
# [ Validation epoch: 3 ]
# Accuarcy: 75.2861755209862
# Average loss: 0.02213058270140061
# Model saved! (time elapsed: 113.46043729782104)
# [ Train epoch: 3 ]
# Train accuarcy: 69.59712335803918
# Train average loss: 0.025135381541336467
# [ Validation epoch: 4 ]
# Accuarcy: 74.14147343704138
# Average loss: 0.020785733694410197
# Model saved! (time elapsed: 148.71583127975464)
# [ Train epoch: 4 ]
# Train accuarcy: 71.30696411535921
# Train average loss: 0.024044274787363255
# [ Validation epoch: 5 ]
# Accuarcy: 79.42471382447901
# Average loss: 0.017972701730215902
# Model saved! (time elapsed: 184.58434772491455)
# [ Train epoch: 5 ]
# Train accuarcy: 72.84802230865193
# Train average loss: 0.022633687660088234
# [ Validation epoch: 6 ]
# Accuarcy: 75.25682418550043
# Average loss: 0.020776626543806975
# Model saved! (time elapsed: 220.62948870658875)
# [ Train epoch: 6 ]
# Train accuarcy: 73.70661187348647
# Train average loss: 0.022183139321388864
# [ Validation epoch: 7 ]
# Accuarcy: 71.1476372174934
# Average loss: 0.024569671551853044
# Model saved! (time elapsed: 257.04310941696167)
# [ Train epoch: 7 ]
# Train accuarcy: 75.26234681147722
# Train average loss: 0.021365705667863354
# [ Validation epoch: 8 ]
# Accuarcy: 81.5086586439683
# Average loss: 0.01646264272244193
# Model saved! (time elapsed: 293.74609303474426)
# [ Train epoch: 8 ]
# Train accuarcy: 75.57789682248477
# Train average loss: 0.02053333812023439
# [ Validation epoch: 9 ]
# Accuarcy: 80.92163193425301
# Average loss: 0.017322024555195104
# Model saved! (time elapsed: 329.5728328227997)
# [ Train epoch: 9 ]
# Train accuarcy: 76.1576282380568
# Train average loss: 0.0201469715092794
# [ Validation epoch: 10 ]
# Accuarcy: 82.94687408277076
# Average loss: 0.015496211599351935
# Model saved! (time elapsed: 366.03359150886536)
# [ Train epoch: 10 ]
# Train accuarcy: 76.5025317384604
# Train average loss: 0.01989377226970022
# [ Validation epoch: 11 ]
# Accuarcy: 81.77282066334018
# Average loss: 0.015998005219698304
# Model saved! (time elapsed: 402.5734272003174)
# [ Train epoch: 11 ]
# Train accuarcy: 77.20701548396566
# Train average loss: 0.01933696693699437
# [ Validation epoch: 12 ]
# Accuarcy: 79.04314646316408
# Average loss: 0.017467463680436123
# Model saved! (time elapsed: 439.1113805770874)
# [ Train epoch: 12 ]
# Train accuarcy: 77.22169222866368
# Train average loss: 0.019158797416927057
# [ Validation epoch: 13 ]
# Accuarcy: 83.62195479894335
# Average loss: 0.014626021460595284
# Model saved! (time elapsed: 476.18132853507996)
# [ Train epoch: 13 ]
# Train accuarcy: 77.92617597416893
# Train average loss: 0.01868316071691504
# [ Validation epoch: 14 ]
# Accuarcy: 76.22541825653067
# Average loss: 0.02094383805876503
# Model saved! (time elapsed: 513.038568019867)
# [ Train epoch: 14 ]
# Train accuarcy: 78.32978645336465
# Train average loss: 0.018508820473784753
# [ Validation epoch: 15 ]
# Accuarcy: 82.21309069562665
# Average loss: 0.015120463686882312
# Model saved! (time elapsed: 548.9807364940643)
# [ Train epoch: 15 ]
# Train accuarcy: 78.85081089014457
# Train average loss: 0.017866447070396033
# [ Validation epoch: 16 ]
# Accuarcy: 83.71000880540065
# Average loss: 0.01517844559214211
# Model saved! (time elapsed: 585.5811922550201)
# [ Train epoch: 16 ]
# Train accuarcy: 79.5406178909518
# Train average loss: 0.017415205159024255
# [ Validation epoch: 17 ]
# Accuarcy: 82.47725271499853
# Average loss: 0.0159901659799035
# Model saved! (time elapsed: 622.1144642829895)
# [ Train epoch: 17 ]
# Train accuarcy: 79.62867835913994
# Train average loss: 0.017466704608750744
# [ Validation epoch: 18 ]
# Accuarcy: 83.65130613442912
# Average loss: 0.014383862510712784
# Model saved! (time elapsed: 658.7221660614014)
# [ Train epoch: 18 ]
# Train accuarcy: 79.62133998679093
# Train average loss: 0.0173386025189951
# [ Validation epoch: 19 ]
# Accuarcy: 85.2362782506604
# Average loss: 0.013303479824312488
# Model saved! (time elapsed: 695.5816736221313)
# [ Train epoch: 19 ]
# Train accuarcy: 80.0543039553827
# Train average loss: 0.017007167979723868
# [ Validation epoch: 20 ]
# Accuarcy: 85.2362782506604
# Average loss: 0.013121425077682162
# Model saved! (time elapsed: 732.7455775737762)
# [ Train epoch: 20 ]
# Train accuarcy: 81.1844132971307
# Train average loss: 0.016381917420071848
# [ Validation epoch: 21 ]
# Accuarcy: 83.15233343117112
# Average loss: 0.015511779317433862
# Model saved! (time elapsed: 769.4835844039917)
# [ Train epoch: 21 ]
# Train accuarcy: 80.53863653041755
# Train average loss: 0.016559731974949567
# [ Validation epoch: 22 ]
# Accuarcy: 85.99941297329029
# Average loss: 0.012556922684623448
# Model saved! (time elapsed: 806.4648756980896)
# [ Train epoch: 22 ]
# Train accuarcy: 80.75878770088794
# Train average loss: 0.01633474229071367
# [ Validation epoch: 23 ]
# Accuarcy: 86.46903434106252
# Average loss: 0.012403915212813591
# Model saved! (time elapsed: 843.313440322876)
# [ Train epoch: 23 ]
# Train accuarcy: 81.2431202759228
# Train average loss: 0.016230692661472538
# [ Validation epoch: 24 ]
# Accuarcy: 86.76254769592016
# Average loss: 0.01177515308196362
# Model saved! (time elapsed: 880.7182912826538)
# [ Train epoch: 24 ]
# Train accuarcy: 81.48528656344023
# Train average loss: 0.01573847255463067
# [ Validation epoch: 25 ]
# Accuarcy: 85.64719694746111
# Average loss: 0.012187660379006711
# Model saved! (time elapsed: 917.9468305110931)
# [ Train epoch: 25 ]
# Train accuarcy: 81.8081749467968
# Train average loss: 0.0157299536011264
# [ Validation epoch: 26 ]
# Accuarcy: 84.12092750220135
# Average loss: 0.013277524748190009
# Model saved! (time elapsed: 955.5181784629822)
# [ Train epoch: 26 ]
# Train accuarcy: 81.88155867028694
# Train average loss: 0.015479281378472954
# [ Validation epoch: 27 ]
# Accuarcy: 80.80422659230994
# Average loss: 0.016833014044903016
# Model saved! (time elapsed: 992.768120765686)
# [ Train epoch: 27 ]
# Train accuarcy: 81.6980993615616
# Train average loss: 0.01564836218967348
# [ Validation epoch: 28 ]
# Accuarcy: 85.94071030231875
# Average loss: 0.012862827890178903
# Model saved! (time elapsed: 1029.4322619438171)
# [ Train epoch: 28 ]
# Train accuarcy: 81.83752843619285
# Train average loss: 0.01572423521299447
# [ Validation epoch: 29 ]
# Accuarcy: 84.85471088934547
# Average loss: 0.013032996771725385
# Model saved! (time elapsed: 1066.0461287498474)
# [ Train epoch: 29 ]
# Train accuarcy: 82.483305202906
# Train average loss: 0.015106325783067852
# [ Validation epoch: 30 ]
# Accuarcy: 86.61579101849134
# Average loss: 0.01203402019392055
# Model saved! (time elapsed: 1102.9899978637695)

# %%
import time
import torch.optim as optim


net = LightResNet110()
net = net.to(device)

epoch = 30
learning_rate = 0.002
file_name = "LightResNet110.pt"

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)

train_result = []
val_result = []

start_time = time.time() # 시작 시간

for i in range(epoch):
    train_acc, train_loss = train(net, i, optimizer, criterion, train_dataloader) # 학습(training)
    val_acc, val_loss = validate(net, i + 1, val_dataloader) # 검증(validation)

    # 학습된 모델 저장하기
    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print(f'Model saved! (time elapsed: {time.time() - start_time})')

    # 현재 epoch에서의 정확도(accuracy)와 손실(loss) 값 저장하기
    train_result.append((train_acc, train_loss))
    val_result.append((val_acc, val_loss))
# Out:
# [ Train epoch: 0 ]
# Train accuarcy: 45.453878329786455
# Train average loss: 0.04130317910345493
# [ Validation epoch: 1 ]
# Accuarcy: 59.964778397417085
# Average loss: 0.0315408072130121
# Model saved! (time elapsed: 68.13305139541626)
# [ Train epoch: 1 ]
# Train accuarcy: 57.42276363102664
# Train average loss: 0.03378630909608659
# [ Validation epoch: 2 ]
# Accuarcy: 65.336072791312
# Average loss: 0.027739244645244396
# Model saved! (time elapsed: 139.12796139717102)
# [ Train epoch: 2 ]
# Train accuarcy: 62.09730681734791
# Train average loss: 0.030742091343321856
# [ Validation epoch: 3 ]
# Accuarcy: 64.13266803639566
# Average loss: 0.028370789761483092
# Model saved! (time elapsed: 207.75160145759583)
# [ Train epoch: 3 ]
# Train accuarcy: 65.15740808688633
# Train average loss: 0.02848872256758383
# [ Validation epoch: 4 ]
# Accuarcy: 74.72850014675667
# Average loss: 0.022059739799418335
# Model saved! (time elapsed: 276.7765998840332)
# [ Train epoch: 4 ]
# Train accuarcy: 67.53504072796653
# Train average loss: 0.026719100780442272
# [ Validation epoch: 5 ]
# Accuarcy: 72.17493395949516
# Average loss: 0.022868654710091137
# Model saved! (time elapsed: 345.98225593566895)
# [ Train epoch: 5 ]
# Train accuarcy: 69.10545241065532
# Train average loss: 0.025577653061926317
# [ Validation epoch: 6 ]
# Accuarcy: 76.92985030818902
# Average loss: 0.020730176567156575
# Model saved! (time elapsed: 414.5102083683014)
# [ Train epoch: 6 ]
# Train accuarcy: 70.75658618918324
# Train average loss: 0.024466427658312282
# [ Validation epoch: 7 ]
# Accuarcy: 78.07455239213384
# Average loss: 0.01894499724093931
# Model saved! (time elapsed: 484.0502438545227)
# [ Train epoch: 7 ]
# Train accuarcy: 72.39304322301314
# Train average loss: 0.023279690697440365
# [ Validation epoch: 8 ]
# Accuarcy: 77.22336366304667
# Average loss: 0.019809449089913556
# Model saved! (time elapsed: 552.8914790153503)
# [ Train epoch: 8 ]
# Train accuarcy: 72.96543626623615
# Train average loss: 0.022773970813248036
# [ Validation epoch: 9 ]
# Accuarcy: 77.83974170824773
# Average loss: 0.01905213122777936
# Model saved! (time elapsed: 622.0975141525269)
# [ Train epoch: 9 ]
# Train accuarcy: 73.6112130329493
# Train average loss: 0.02223588023565744
# [ Validation epoch: 10 ]
# Accuarcy: 76.60698561784561
# Average loss: 0.020092317115571235
# Model saved! (time elapsed: 691.3305997848511)
# [ Train epoch: 10 ]
# Train accuarcy: 74.78535260879137
# Train average loss: 0.02128130592935598
# [ Validation epoch: 11 ]
# Accuarcy: 80.07044320516583
# Average loss: 0.017747404942213003
# Model saved! (time elapsed: 759.84765458107)
# [ Train epoch: 11 ]
# Train accuarcy: 75.54854333308872
# Train average loss: 0.020663134077372657
# [ Validation epoch: 12 ]
# Accuarcy: 82.74141473437041
# Average loss: 0.015293379892937628
# Model saved! (time elapsed: 829.0823225975037)
# [ Train epoch: 12 ]
# Train accuarcy: 75.73200264181405
# Train average loss: 0.020609816255140453
# [ Validation epoch: 13 ]
# Accuarcy: 79.63017317287937
# Average loss: 0.01713771772570088
# Model saved! (time elapsed: 898.0880405902863)
# [ Train epoch: 13 ]
# Train accuarcy: 75.89344683349233
# Train average loss: 0.020168234245954014
# [ Validation epoch: 14 ]
# Accuarcy: 83.26973877311417
# Average loss: 0.015227196120886919
# Model saved! (time elapsed: 967.4704351425171)
# [ Train epoch: 14 ]
# Train accuarcy: 76.74469802597784
# Train average loss: 0.019788245497108895
# [ Validation epoch: 15 ]
# Accuarcy: 81.89022600528324
# Average loss: 0.016101709284634055
# Model saved! (time elapsed: 1036.874015569687)
# [ Train epoch: 15 ]
# Train accuarcy: 76.97218756879724
# Train average loss: 0.019255240061334375
# [ Validation epoch: 16 ]
# Accuarcy: 83.35779277957147
# Average loss: 0.015127702392823612
# Model saved! (time elapsed: 1105.6741170883179)
# [ Train epoch: 16 ]
# Train accuarcy: 78.11697365524327
# Train average loss: 0.018763553267784283
# [ Validation epoch: 17 ]
# Accuarcy: 81.74346932785441
# Average loss: 0.015565057203396696
# Model saved! (time elapsed: 1176.1620633602142)
# [ Train epoch: 17 ]
# Train accuarcy: 77.75005503779262
# Train average loss: 0.018892211976654593
# [ Validation epoch: 18 ]
# Accuarcy: 80.83357792779572
# Average loss: 0.017218257561610318
# Model saved! (time elapsed: 1245.272254228592)
# [ Train epoch: 18 ]
# Train accuarcy: 77.8527922506788
# Train average loss: 0.018739561649212845
# [ Validation epoch: 19 ]
# Accuarcy: 83.68065746991488
# Average loss: 0.014343597889296428
# Model saved! (time elapsed: 1314.850606918335)
# [ Train epoch: 19 ]
# Train accuarcy: 78.44720041094885
# Train average loss: 0.01839751366028618
# [ Validation epoch: 20 ]
# Accuarcy: 83.88611681831523
# Average loss: 0.014594115747676275
# Model saved! (time elapsed: 1383.408141374588)
# [ Train epoch: 20 ]
# Train accuarcy: 79.42320393336757
# Train average loss: 0.0175465815063967
# [ Validation epoch: 21 ]
# Accuarcy: 81.27384796008218
# Average loss: 0.01526138955349442
# Model saved! (time elapsed: 1452.2136671543121)
# [ Train epoch: 21 ]
# Train accuarcy: 79.47457253981067
# Train average loss: 0.017430849245947542
# [ Validation epoch: 22 ]
# Accuarcy: 84.85471088934547
# Average loss: 0.013521717127061569
# Model saved! (time elapsed: 1521.9849004745483)
# [ Train epoch: 22 ]
# Train accuarcy: 79.69472371028105
# Train average loss: 0.017437193820741947
# [ Validation epoch: 23 ]
# Accuarcy: 84.913413560317
# Average loss: 0.013718022396041741
# Model saved! (time elapsed: 1590.6690323352814)
# [ Train epoch: 23 ]
# Train accuarcy: 79.99559697659059
# Train average loss: 0.0169821433674312
# [ Validation epoch: 24 ]
# Accuarcy: 83.915468153801
# Average loss: 0.01341803476437467
# Model saved! (time elapsed: 1659.7309474945068)
# [ Train epoch: 24 ]
# Train accuarcy: 80.08365744477875
# Train average loss: 0.01696194899819642
# [ Validation epoch: 25 ]
# Accuarcy: 84.56119753448782
# Average loss: 0.01356516091362416
# Model saved! (time elapsed: 1728.721718788147)
# [ Train epoch: 25 ]
# Train accuarcy: 80.68540397739781
# Train average loss: 0.01674215297225007
# [ Validation epoch: 26 ]
# Accuarcy: 85.70589961843264
# Average loss: 0.012336171798283382
# Model saved! (time elapsed: 1797.636950969696)
# [ Train epoch: 26 ]
# Train accuarcy: 80.13502605122184
# Train average loss: 0.016733033654055908
# [ Validation epoch: 27 ]
# Accuarcy: 85.41238626357499
# Average loss: 0.013295682545697756
# Model saved! (time elapsed: 1867.311529636383)
# [ Train epoch: 27 ]
# Train accuarcy: 80.52395978571953
# Train average loss: 0.016371151807329717
# [ Validation epoch: 28 ]
# Accuarcy: 85.06017023774582
# Average loss: 0.013668481790847991
# Model saved! (time elapsed: 1935.748465538025)
# [ Train epoch: 28 ]
# Train accuarcy: 80.75878770088794
# Train average loss: 0.016370037013046054
# [ Validation epoch: 29 ]
# Accuarcy: 84.20898150865864
# Average loss: 0.013463564748493919
# Model saved! (time elapsed: 2005.481656551361)
# [ Train epoch: 29 ]
# Train accuarcy: 81.11836794598958
# Train average loss: 0.016194299761176662
# [ Validation epoch: 30 ]
# Accuarcy: 84.88406222483123
# Average loss: 0.013575981413474837
# Model saved! (time elapsed: 2074.6453659534454)

# %% [markdown]
# #### <b>(알아보기) ResNet 아키텍처 살펴보기</b>
#
# * [ResNet (2016 CVPR)](https://arxiv.org/abs/1512.03385) 논문에서 제안된 기본적인 ResNet의 핵심 아이디어를 PyTorch로 구현한 것은 다음과 같습니다.
#     * LightResNet에 비하여 <b>커널의 개수(number of kernels)가 많은</b> 것을 확인할 수 있습니다.
#     * 따라서 ImageNet과 같은 큰 규모의 데이터셋에 대해서 사용하기에 적합합니다.
# * (참고) [PyTorch 공식 ResNet 소스 코드](https://github.com/pytorch/vision/blob/master/torchvision/models/resnet.py)

# %%
# ResNet 클래스 정의
class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=6):
        super(ResNet, self).__init__()
        self.in_planes = 64

        # 64개의 3x3 필터(filter)를 사용
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        # 첫 레이어를 제외하고는 너비와 높이를 줄이기 위해 stride를 2로 설정
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1) # 첫째 블록만 너비와 높이 감소
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes # 다음 레이어를 위해 채널 수 변경
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, out.size()[3])
        out = out.view(out.size(0), -1) # 배치(batch)를 제외한 모든 차원 flatten하기
        out = self.linear(out)
        return out


def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])


def ResNet34():
    return ResNet(BasicBlock, [3, 4, 6, 3])

# %% [markdown]
# #### <b>(알아보기) ResNet-18 학습하기</b>
#
# * PyTorch로 구현된 ResNet-18 모델을 학습해 봅시다.

# %%
import time
import torch.optim as optim


net = ResNet18()
net = net.to(device)

epoch = 30
learning_rate = 0.002
file_name = "ResNet18.pt"

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)

train_result = []
val_result = []

start_time = time.time() # 시작 시간

for i in range(epoch):
    train_acc, train_loss = train(net, i, optimizer, criterion, train_dataloader) # 학습(training)
    val_acc, val_loss = validate(net, i + 1, val_dataloader) # 검증(validation)

    # 학습된 모델 저장하기
    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print(f'Model saved! (time elapsed: {time.time() - start_time})')

    # 현재 epoch에서의 정확도(accuracy)와 손실(loss) 값 저장하기
    train_result.append((train_acc, train_loss))
    val_result.append((val_acc, val_loss))
# Out:
# [ Train epoch: 0 ]
# Train accuarcy: 54.634182138401705
# Train average loss: 0.03552350132220593
# [ Validation epoch: 1 ]
# Accuarcy: 64.04461402993836
# Average loss: 0.030625102927267008
# Model saved! (time elapsed: 56.392067432403564)
# [ Train epoch: 1 ]
# Train accuarcy: 66.28017905628532
# Train average loss: 0.027683555574666258
# [ Validation epoch: 2 ]
# Accuarcy: 76.22541825653067
# Average loss: 0.020909708783813402
# Model saved! (time elapsed: 112.09643793106079)
# [ Train epoch: 2 ]
# Train accuarcy: 70.65384897629706
# Train average loss: 0.024552799536580516
# [ Validation epoch: 3 ]
# Accuarcy: 75.72644555327267
# Average loss: 0.020803920747529105
# Model saved! (time elapsed: 168.0892436504364)
# [ Train epoch: 3 ]
# Train accuarcy: 73.06083510677331
# Train average loss: 0.022823793206008802
# [ Validation epoch: 4 ]
# Accuarcy: 75.2861755209862
# Average loss: 0.020782165577028867
# Model saved! (time elapsed: 224.10530710220337)
# [ Train epoch: 4 ]
# Train accuarcy: 75.04953401335584
# Train average loss: 0.02116022261676045
# [ Validation epoch: 5 ]
# Accuarcy: 80.33460522453771
# Average loss: 0.016757638259545637
# Model saved! (time elapsed: 280.1415412425995)
# [ Train epoch: 5 ]
# Train accuarcy: 76.37044103617818
# Train average loss: 0.01991496870949358
# [ Validation epoch: 6 ]
# Accuarcy: 81.5086586439683
# Average loss: 0.015801148935780693
# Model saved! (time elapsed: 336.057856798172)
# [ Train epoch: 6 ]
# Train accuarcy: 76.81074337711895
# Train average loss: 0.019498130532819895
# [ Validation epoch: 7 ]
# Accuarcy: 81.44995597299678
# Average loss: 0.015548953277504196
# Model saved! (time elapsed: 392.00325560569763)
# [ Train epoch: 7 ]
# Train accuarcy: 77.7940852718867
# Train average loss: 0.018866681710127262
# [ Validation epoch: 8 ]
# Accuarcy: 84.17963017317288
# Average loss: 0.013664885371319878
# Model saved! (time elapsed: 448.02228832244873)
# [ Train epoch: 8 ]
# Train accuarcy: 79.0416085712189
# Train average loss: 0.017912666459264467
# [ Validation epoch: 9 ]
# Accuarcy: 85.08952157323158
# Average loss: 0.013463371545120107
# Model saved! (time elapsed: 504.14816403388977)
# [ Train epoch: 9 ]
# Train accuarcy: 79.08563880531298
# Train average loss: 0.0176577540355776
# [ Validation epoch: 10 ]
# Accuarcy: 83.09363076019959
# Average loss: 0.015103666531154407
# Model saved! (time elapsed: 560.1805219650269)
# [ Train epoch: 10 ]
# Train accuarcy: 80.3918690834373
# Train average loss: 0.01709865421382611
# [ Validation epoch: 11 ]
# Accuarcy: 82.24244203111242
# Average loss: 0.015596012194239922
# Model saved! (time elapsed: 616.2508070468903)
# [ Train epoch: 11 ]
# Train accuarcy: 80.94224700961327
# Train average loss: 0.01624337270765143
# [ Validation epoch: 12 ]
# Accuarcy: 85.55914294100381
# Average loss: 0.012451799748788525
# Model saved! (time elapsed: 672.3249988555908)
# [ Train epoch: 12 ]
# Train accuarcy: 81.61003889337346
# Train average loss: 0.015776265370195816
# [ Validation epoch: 13 ]
# Accuarcy: 85.91135896683299
# Average loss: 0.012401989475001958
# Model saved! (time elapsed: 728.4691355228424)
# [ Train epoch: 13 ]
# Train accuarcy: 81.30182725471491
# Train average loss: 0.015962627105162816
# [ Validation epoch: 14 ]
# Accuarcy: 86.58643968300558
# Average loss: 0.012299993589612302
# Model saved! (time elapsed: 784.5571179389954)
# [ Train epoch: 14 ]
# Train accuarcy: 81.925588904381
# Train average loss: 0.015660236149407397
# [ Validation epoch: 15 ]
# Accuarcy: 83.29909010859994
# Average loss: 0.01429344191469333
# Model saved! (time elapsed: 840.6422958374023)
# [ Train epoch: 15 ]
# Train accuarcy: 82.18243193659646
# Train average loss: 0.015174747478929577
# [ Validation epoch: 16 ]
# Accuarcy: 85.76460228940417
# Average loss: 0.012752274200560796
# Model saved! (time elapsed: 896.5983777046204)
# [ Train epoch: 16 ]
# Train accuarcy: 82.51265869230205
# Train average loss: 0.014840699627874113
# [ Validation epoch: 17 ]
# Accuarcy: 84.35573818608746
# Average loss: 0.0133746397007166
# Model saved! (time elapsed: 952.5179381370544)
# [ Train epoch: 17 ]
# Train accuarcy: 83.03368312908196
# Train average loss: 0.014693979498942373
# [ Validation epoch: 18 ]
# Accuarcy: 87.17346639272087
# Average loss: 0.01141935535101097
# Model saved! (time elapsed: 1008.4966914653778)
# [ Train epoch: 18 ]
# Train accuarcy: 82.97497615028986
# Train average loss: 0.014324165126709977
# [ Validation epoch: 19 ]
# Accuarcy: 87.3202230701497
# Average loss: 0.011493727877530528
# Model saved! (time elapsed: 1064.543095111847)
# [ Train epoch: 19 ]
# Train accuarcy: 82.94562266089382
# Train average loss: 0.014492610786712956
# [ Validation epoch: 20 ]
# Accuarcy: 87.96595245083651
# Average loss: 0.010962819752190727
# Model saved! (time elapsed: 1120.5771708488464)
# [ Train epoch: 20 ]
# Train accuarcy: 83.36390988478756
# Train average loss: 0.014021456331274888
# [ Validation epoch: 21 ]
# Accuarcy: 87.6430877604931
# Average loss: 0.010934485408491427
# Model saved! (time elapsed: 1176.5525619983673)
# [ Train epoch: 21 ]
# Train accuarcy: 83.98767153445365
# Train average loss: 0.013677046207039006
# [ Validation epoch: 22 ]
# Accuarcy: 88.11270912826534
# Average loss: 0.011205443542200273
# Model saved! (time elapsed: 1232.49391579628)
# [ Train epoch: 22 ]
# Train accuarcy: 83.61341454465399
# Train average loss: 0.013903976396549611
# [ Validation epoch: 23 ]
# Accuarcy: 88.40622248312299
# Average loss: 0.010049392569002114
# Model saved! (time elapsed: 1288.4434094429016)
# [ Train epoch: 23 ]
# Train accuarcy: 84.22249944962208
# Train average loss: 0.01332762242435158
# [ Validation epoch: 24 ]
# Accuarcy: 88.17141179923686
# Average loss: 0.011050569360989925
# Model saved! (time elapsed: 1344.5159559249878)
# [ Train epoch: 24 ]
# Train accuarcy: 84.24451456666911
# Train average loss: 0.013455687868644987
# [ Validation epoch: 25 ]
# Accuarcy: 86.70384502494863
# Average loss: 0.012711640194797572
# Model saved! (time elapsed: 1400.5662755966187)
# [ Train epoch: 25 ]
# Train accuarcy: 85.05173552506054
# Train average loss: 0.013233664584932301
# [ Validation epoch: 26 ]
# Accuarcy: 88.08335779277957
# Average loss: 0.01063289316625304
# Model saved! (time elapsed: 1456.622546672821)
# [ Train epoch: 26 ]
# Train accuarcy: 84.67014016291186
# Train average loss: 0.012937242616961163
# [ Validation epoch: 27 ]
# Accuarcy: 88.05400645729381
# Average loss: 0.01054535748446341
# Model saved! (time elapsed: 1512.6548464298248)
# [ Train epoch: 27 ]
# Train accuarcy: 84.84626109928818
# Train average loss: 0.01287252098866479
# [ Validation epoch: 28 ]
# Accuarcy: 89.19870854123863
# Average loss: 0.010300897373450198
# Model saved! (time elapsed: 1568.5828454494476)
# [ Train epoch: 28 ]
# Train accuarcy: 85.04439715271153
# Train average loss: 0.012630687983490763
# [ Validation epoch: 29 ]
# Accuarcy: 88.52362782506604
# Average loss: 0.010554869175132223
# Model saved! (time elapsed: 1624.550882101059)
# [ Train epoch: 29 ]
# Train accuarcy: 85.56542158949145
# Train average loss: 0.012323715384860132
# [ Validation epoch: 30 ]
# Accuarcy: 87.26152039917817
# Average loss: 0.010899315978254711
# Model saved! (time elapsed: 1680.5771353244781)

# %%
# 정확도(accuracy) 커브 시각화
plt.subplot(211)
plt.plot([i for i in range(epoch)], [i[0] for i in train_result])
plt.plot([i for i in range(epoch)], [i[0] for i in val_result])
plt.title("Accuracy Curve")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(["train", "val"])

# 손실(loss) 커브 시각화
plt.subplot(212)
plt.plot([i for i in range(epoch)], [i[1] for i in train_result])
plt.plot([i for i in range(epoch)], [i[1] for i in val_result])
plt.title("Loss Curve")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(["train", "val"])

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns


net = ResNet18()
net = net.to(device)

file_name = "./checkpoint/ResNet18.pt"
checkpoint = torch.load(file_name)
net.load_state_dict(checkpoint['net'])

# 평가 데이터셋을 이용해 혼동 행렬(confusion matrix) 계산하기
confusion_matrix = get_confusion_matrix(net, 6, val_dataloader)
print("[ 각 클래스당 데이터 개수 ]")
print(confusion_matrix.sum(1))

print("[ 혼동 행렬(confusion matrix) 시각화 ]")
res = pd.DataFrame(confusion_matrix.numpy(), index = [i for i in range(6)], columns = [i for i in range(6)])
res.index.name = 'True label'
res.columns.name = 'Predicted label'
plt.figure(figsize = (10, 7))
sns.heatmap(res, annot=True, fmt="d", cmap='Blues')
plt.show()

print("[ 각 클래스에 따른 정확도 ]")
# (각 클래스마다 정답 개수 / 각 클래스마다 데이터의 개수)
print(confusion_matrix.diag() / confusion_matrix.sum(1))

print("[ 전체 평균 정확도 ]")
print(confusion_matrix.diag().sum() / confusion_matrix.sum())
# Out:
# [ 각 클래스당 데이터 개수 ]
# tensor([523, 540, 594, 599, 560, 591])
# [ 혼동 행렬(confusion matrix) 시각화 ]
# [ 각 클래스에 따른 정확도 ]
# tensor([0.9446, 0.9667, 0.8114, 0.8564, 0.8946, 0.7800])
# [ 전체 평균 정확도 ]
# tensor(0.8726)

# %% [markdown]
# #### <b>(알아보기) Input Mixup 살펴보기</b>
#
# * Mixup은 대표적인 데이터 증진(data augmentation) 기법으로 정확도 향상에 도움이 됩니다.
#     * 일반적으로 Mixup을 사용하는 경우 더 많은 횟수(1.5배가량)의 epoch이 요구됩니다.

# %%
mixup_alpha = 1.0


def mixup_data(x, y):
    lam = np.random.beta(mixup_alpha, mixup_alpha)
    batch_size = x.size()[0]
    index = torch.randperm(batch_size).cuda()
    mixed_x = lam * x + (1 - lam) * x[index]
    y_a, y_b = y, y[index]
    return mixed_x, y_a, y_b, lam


def mixup_criterion(criterion, pred, y_a, y_b, lam):
    return lam * criterion(pred, y_a) + (1 - lam) * criterion(pred, y_b)


def train_with_mixup(net, epoch, optimizer, criterion, train_dataloader):
    print('[ Train epoch: %d ]' % epoch)
    net.train() # 모델을 학습 모드로 설정
    train_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(train_dataloader):
        inputs, targets = inputs.to(device), targets.to(device)
        inputs, targets_a, targets_b, lam = mixup_data(inputs, targets) # Mixup 진행
        optimizer.zero_grad() # 기울기(gradient) 초기화

        outputs = net(inputs) # 모델 입력하여 결과 계산
        loss = mixup_criterion(criterion, outputs, targets_a, targets_b, lam) # 손실(loss) 값 계산
        loss.backward() # 역전파를 통해 기울기(gradient) 계산

        optimizer.step() # 계산된 기울기를 이용해 모델 가중치 업데이트
        train_loss += loss.item()
        _, predicted = outputs.max(1)

        total += targets.size(0)
        correct += (lam * predicted.eq(targets_a).sum().item() + (1 - lam) * predicted.eq(targets_b).sum().item())

    print('Train accuarcy:', 100. * correct / total)
    print('Train average loss:', train_loss / total)
    return (100. * correct / total, train_loss / total)

# %% [markdown]
# #### <b>Problem 6. Mixup 결과 분석하기</b>
#
# * Mixup을 사용하여 ResNet-18에 대하여 50번 epoch만큼 학습을 진행한 뒤에 성능이 얼마나 개선되었는지 쓰세요.
#     * Mixup을 적용했을 때의 검증 정확도(validation accuracy): 86.08746697974757

# %%
import time
import torch.optim as optim


net = ResNet18()
net = net.to(device)

epoch = 50
learning_rate = 0.002
file_name = "ResNet18.pt"

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)

train_result = []
val_result = []

start_time = time.time() # 시작 시간

for i in range(epoch):
    train_acc, train_loss = train_with_mixup(net, i, optimizer, criterion, train_dataloader) # 학습(training)
    val_acc, val_loss = validate(net, i + 1, val_dataloader) # 검증(validation)

    # 학습된 모델 저장하기
    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print(f'Model saved! (time elapsed: {time.time() - start_time})')

    # 현재 epoch에서의 정확도(accuracy)와 손실(loss) 값 저장하기
    train_result.append((train_acc, train_loss))
    val_result.append((val_acc, val_loss))
# Out:
# [ Train epoch: 0 ]
# Train accuarcy: 42.94972987305213
# Train average loss: 0.04550202407061489
# [ Validation epoch: 1 ]
# Accuarcy: 62.66510126210743
# Average loss: 0.03173401592272553
# Model saved! (time elapsed: 48.89790892601013)
# [ Train epoch: 1 ]
# Train accuarcy: 51.74115585057042
# Train average loss: 0.040692587569602
# [ Validation epoch: 2 ]
# Accuarcy: 59.31904901673026
# Average loss: 0.03309938886279685
# Model saved! (time elapsed: 90.85291481018066)
# [ Train epoch: 2 ]
# Train accuarcy: 53.38956771726453
# Train average loss: 0.03959180122164696
# [ Validation epoch: 3 ]
# Accuarcy: 73.29028470795421
# Average loss: 0.02382650331979208
# Model saved! (time elapsed: 134.1440839767456)
# [ Train epoch: 3 ]
# Train accuarcy: 55.73190576593903
# Train average loss: 0.038197015293575116
# [ Validation epoch: 4 ]
# Accuarcy: 77.3701203404755
# Average loss: 0.022133805778392572
# Model saved! (time elapsed: 177.82809281349182)
# [ Train epoch: 4 ]
# Train accuarcy: 57.63178837139048
# Train average loss: 0.03699144405883713
# [ Validation epoch: 5 ]
# Accuarcy: 78.54417375990607
# Average loss: 0.020249086494210672
# Model saved! (time elapsed: 221.199289560318)
# [ Train epoch: 5 ]
# Train accuarcy: 57.88409495885659
# Train average loss: 0.03668440034316537
# [ Validation epoch: 6 ]
# Accuarcy: 77.31141766950397
# Average loss: 0.022739215517519926
# Model saved! (time elapsed: 265.21403217315674)
# [ Train epoch: 6 ]
# Train accuarcy: 58.468629645007915
# Train average loss: 0.03645201783769154
# [ Validation epoch: 7 ]
# Accuarcy: 83.18168476665689
# Average loss: 0.019650773416700552
# Model saved! (time elapsed: 308.46523213386536)
# [ Train epoch: 7 ]
# Train accuarcy: 58.89071439056407
# Train average loss: 0.03595650327733164
# [ Validation epoch: 8 ]
# Accuarcy: 79.74757851482242
# Average loss: 0.020309127073397132
# Model saved! (time elapsed: 352.57262921333313)
# [ Train epoch: 8 ]
# Train accuarcy: 59.74325726681119
# Train average loss: 0.03516320904894953
# [ Validation epoch: 9 ]
# Accuarcy: 81.89022600528324
# Average loss: 0.017823915450776606
# Model saved! (time elapsed: 395.92137575149536)
# [ Train epoch: 9 ]
# Train accuarcy: 60.790465306661254
# Train average loss: 0.034653012961785634
# [ Validation epoch: 10 ]
# Accuarcy: 82.56530672145583
# Average loss: 0.018420407630006765
# Model saved! (time elapsed: 439.54475593566895)
# [ Train epoch: 10 ]
# Train accuarcy: 60.73221201381443
# Train average loss: 0.03460889654918174
# [ Validation epoch: 11 ]
# Accuarcy: 79.74757851482242
# Average loss: 0.02042855775037888
# Model saved! (time elapsed: 483.1163663864136)
# [ Train epoch: 11 ]
# Train accuarcy: 61.152580984180794
# Train average loss: 0.03405797743758811
# [ Validation epoch: 12 ]
# Accuarcy: 80.04109186968007
# Average loss: 0.018631708422538504
# Model saved! (time elapsed: 526.4758744239807)
# [ Train epoch: 12 ]
# Train accuarcy: 60.55306913489033
# Train average loss: 0.034556815471934
# [ Validation epoch: 13 ]
# Accuarcy: 83.7393601408864
# Average loss: 0.016352065622649098
# Model saved! (time elapsed: 570.4535167217255)
# [ Train epoch: 13 ]
# Train accuarcy: 61.72751780140408
# Train average loss: 0.033797100992259445
# [ Validation epoch: 14 ]
# Accuarcy: 85.76460228940417
# Average loss: 0.016083487272612468
# Model saved! (time elapsed: 613.778656244278)
# [ Train epoch: 14 ]
# Train accuarcy: 62.255669752002646
# Train average loss: 0.03337933777573086
# [ Validation epoch: 15 ]
# Accuarcy: 84.67860287643087
# Average loss: 0.016519235224537673
# Model saved! (time elapsed: 657.7423248291016)
# [ Train epoch: 15 ]
# Train accuarcy: 62.5408900145987
# Train average loss: 0.03312998379791107
# [ Validation epoch: 16 ]
# Accuarcy: 83.12298209568536
# Average loss: 0.01680009259938284
# Model saved! (time elapsed: 701.1826145648956)
# [ Train epoch: 16 ]
# Train accuarcy: 62.61436849853936
# Train average loss: 0.03321529811035907
# [ Validation epoch: 17 ]
# Accuarcy: 80.92163193425301
# Average loss: 0.01770003882187848
# Model saved! (time elapsed: 744.7170121669769)
# [ Train epoch: 17 ]
# Train accuarcy: 63.01735772703496
# Train average loss: 0.0327956576471398
# [ Validation epoch: 18 ]
# Accuarcy: 85.08952157323158
# Average loss: 0.015396702436537277
# Model saved! (time elapsed: 788.4995920658112)
# [ Train epoch: 18 ]
# Train accuarcy: 63.134601173258496
# Train average loss: 0.03251777183522287
# [ Validation epoch: 19 ]
# Accuarcy: 85.47108893454651
# Average loss: 0.015135779307670245
# Model saved! (time elapsed: 831.894727230072)
# [ Train epoch: 19 ]
# Train accuarcy: 64.46292384824913
# Train average loss: 0.031592742639792726
# [ Validation epoch: 20 ]
# Accuarcy: 85.3243322571177
# Average loss: 0.014946152973566931
# Model saved! (time elapsed: 876.0059003829956)
# [ Train epoch: 20 ]
# Train accuarcy: 63.09179028706665
# Train average loss: 0.03252743395940568
# [ Validation epoch: 21 ]
# Accuarcy: 84.09157616671558
# Average loss: 0.016306919132400056
# Model saved! (time elapsed: 919.3893523216248)
# [ Train epoch: 21 ]
# Train accuarcy: 63.257477876173176
# Train average loss: 0.032521832828660995
# [ Validation epoch: 22 ]
# Accuarcy: 85.91135896683299
# Average loss: 0.015352505793626056
# Model saved! (time elapsed: 962.8940696716309)
# [ Train epoch: 22 ]
# Train accuarcy: 64.50397727303455
# Train average loss: 0.03162608780592861
# [ Validation epoch: 23 ]
# Accuarcy: 84.76665688288817
# Average loss: 0.015860960867211095
# Model saved! (time elapsed: 1006.5133175849915)
# [ Train epoch: 23 ]
# Train accuarcy: 63.809971157775294
# Train average loss: 0.032129331879739306
# [ Validation epoch: 24 ]
# Accuarcy: 86.46903434106252
# Average loss: 0.015144912814128284
# Model saved! (time elapsed: 1050.0763115882874)
# [ Train epoch: 24 ]
# Train accuarcy: 65.28266362229556
# Train average loss: 0.030860653040894952
# [ Validation epoch: 25 ]
# Accuarcy: 85.41238626357499
# Average loss: 0.016411067358657414
# Model saved! (time elapsed: 1093.9423220157623)
# [ Train epoch: 25 ]
# Train accuarcy: 64.60377371156025
# Train average loss: 0.03132728484683458
# [ Validation epoch: 26 ]
# Accuarcy: 87.90724977986498
# Average loss: 0.013703289648147843
# Model saved! (time elapsed: 1137.3291375637054)
# [ Train epoch: 26 ]
# Train accuarcy: 64.39187403011113
# Train average loss: 0.03160092391419797
# [ Validation epoch: 27 ]
# Accuarcy: 87.3202230701497
# Average loss: 0.014953677618227154
# Model saved! (time elapsed: 1181.583913564682)
# [ Train epoch: 27 ]
# Train accuarcy: 62.851089376860465
# Train average loss: 0.03248507015605556
# [ Validation epoch: 28 ]
# Accuarcy: 88.02465512180804
# Average loss: 0.014859198474240226
# Model saved! (time elapsed: 1225.0454347133636)
# [ Train epoch: 28 ]
# Train accuarcy: 65.48633340149188
# Train average loss: 0.03069206480454338
# [ Validation epoch: 29 ]
# Accuarcy: 86.82125036689169
# Average loss: 0.014802334934586754
# Model saved! (time elapsed: 1268.7673044204712)
# [ Train epoch: 29 ]
# Train accuarcy: 65.55570004262819
# Train average loss: 0.030558461338826195
# [ Validation epoch: 30 ]
# Accuarcy: 82.53595538597006
# Average loss: 0.016223197004156167
# Model saved! (time elapsed: 1312.2918589115143)
# [ Train epoch: 30 ]
# Train accuarcy: 64.78802563707895
# Train average loss: 0.031128764935474784
# [ Validation epoch: 31 ]
# Accuarcy: 85.97006163780452
# Average loss: 0.014677868854765113
# Model saved! (time elapsed: 1355.6776604652405)
# [ Train epoch: 31 ]
# Train accuarcy: 65.26179596791825
# Train average loss: 0.030792125002989865
# [ Validation epoch: 32 ]
# Accuarcy: 82.88817141179923
# Average loss: 0.01721539458362175
# Model saved! (time elapsed: 1399.5953452587128)
# [ Train epoch: 32 ]
# Train accuarcy: 64.65475756401784
# Train average loss: 0.03098333312986252
# [ Validation epoch: 33 ]
# Accuarcy: 86.87995303786322
# Average loss: 0.013569313408448825
# Model saved! (time elapsed: 1442.9543216228485)
# [ Train epoch: 33 ]
# Train accuarcy: 65.14143144610797
# Train average loss: 0.030724106876325423
# [ Validation epoch: 34 ]
# Accuarcy: 86.6451423539771
# Average loss: 0.013584812711087847
# Model saved! (time elapsed: 1487.26833486557)
# [ Train epoch: 34 ]
# Train accuarcy: 65.4946452693536
# Train average loss: 0.03039545160427459
# [ Validation epoch: 35 ]
# Accuarcy: 84.88406222483123
# Average loss: 0.015042759760195187
# Model saved! (time elapsed: 1530.644244670868)
# [ Train epoch: 35 ]
# Train accuarcy: 65.32105013497402
# Train average loss: 0.03029963176213891
# [ Validation epoch: 36 ]
# Accuarcy: 87.34957440563545
# Average loss: 0.014043577822345703
# Model saved! (time elapsed: 1574.1712219715118)
# [ Train epoch: 36 ]
# Train accuarcy: 65.24922591136183
# Train average loss: 0.030492780333596873
# [ Validation epoch: 37 ]
# Accuarcy: 88.46492515409452
# Average loss: 0.012755653079318132
# Model saved! (time elapsed: 1617.980050086975)
# [ Train epoch: 37 ]
# Train accuarcy: 65.64008531420751
# Train average loss: 0.030366604038770964
# [ Validation epoch: 38 ]
# Accuarcy: 89.1400058702671
# Average loss: 0.013168760455350984
# Model saved! (time elapsed: 1661.2980601787567)
# [ Train epoch: 38 ]
# Train accuarcy: 65.29413485347379
# Train average loss: 0.030421932705291834
# [ Validation epoch: 39 ]
# Accuarcy: 87.58438508952158
# Average loss: 0.013712873062955903
# Model saved! (time elapsed: 1705.4337289333344)
# [ Train epoch: 39 ]
# Train accuarcy: 65.4644977185393
# Train average loss: 0.030338518677449255
# [ Validation epoch: 40 ]
# Accuarcy: 88.34751981215145
# Average loss: 0.013812291992176023
# Model saved! (time elapsed: 1749.3704390525818)
# [ Train epoch: 40 ]
# Train accuarcy: 66.99148239521314
# Train average loss: 0.029546718832034045
# [ Validation epoch: 41 ]
# Accuarcy: 87.40827707660698
# Average loss: 0.013700586314211153
# Model saved! (time elapsed: 1793.2503552436829)
# [ Train epoch: 41 ]
# Train accuarcy: 66.52716491595004
# Train average loss: 0.02973662041127135
# [ Validation epoch: 42 ]
# Accuarcy: 87.67243909597887
# Average loss: 0.013259877793278762
# Model saved! (time elapsed: 1836.8437733650208)
# [ Train epoch: 42 ]
# Train accuarcy: 67.72126192210644
# Train average loss: 0.029001318619782605
# [ Validation epoch: 43 ]
# Accuarcy: 88.5529791605518
# Average loss: 0.012839680416758262
# Model saved! (time elapsed: 1880.3036043643951)
# [ Train epoch: 43 ]
# Train accuarcy: 66.90764484843478
# Train average loss: 0.02945716654711112
# [ Validation epoch: 44 ]
# Accuarcy: 86.38098033460523
# Average loss: 0.014916404959285647
# Model saved! (time elapsed: 1924.3129506111145)
# [ Train epoch: 44 ]
# Train accuarcy: 65.93850785930573
# Train average loss: 0.030104256587375974
# [ Validation epoch: 45 ]
# Accuarcy: 88.58233049603757
# Average loss: 0.013650332272735061
# Model saved! (time elapsed: 1967.8550777435303)
# [ Train epoch: 45 ]
# Train accuarcy: 67.42358311492211
# Train average loss: 0.02915591687355509
# [ Validation epoch: 46 ]
# Accuarcy: 88.61168183152333
# Average loss: 0.012982712411831509
# Model saved! (time elapsed: 2012.1332559585571)
# [ Train epoch: 46 ]
# Train accuarcy: 67.49754529698005
# Train average loss: 0.02907396861390094
# [ Validation epoch: 47 ]
# Accuarcy: 87.99530378632228
# Average loss: 0.013260040302097466
# Model saved! (time elapsed: 2055.660082101822)
# [ Train epoch: 47 ]
# Train accuarcy: 66.77137382866165
# Train average loss: 0.029295316764130372
# [ Validation epoch: 48 ]
# Accuarcy: 86.90930437334899
# Average loss: 0.013929630387798585
# Model saved! (time elapsed: 2101.2378754615784)
# [ Train epoch: 48 ]
# Train accuarcy: 67.01533976847152
# Train average loss: 0.029401328459238808
# [ Validation epoch: 49 ]
# Accuarcy: 89.46287056061051
# Average loss: 0.011967578883705721
# Model saved! (time elapsed: 2145.1658992767334)
# [ Train epoch: 49 ]
# Train accuarcy: 66.58937495996535
# Train average loss: 0.02947214825790032
# [ Validation epoch: 50 ]
# Accuarcy: 86.08746697974757
# Average loss: 0.014497984975952538
# Model saved! (time elapsed: 2188.8708035945892)

# %% [markdown]
# #### <b>(알아보기) Transfer Learning 살펴보기</b>
#
# * 전이 학습(Transfer Learning)은 <b>단기간에 우수한 정확도</b>를 얻기 위해 효과적으로 사용할 수 있는 기법입니다.
#     * 본 실습에서는 미세 조정(fine-tuning) 기법을 사용합니다.
#     * 적은 epoch만으로도 빠르게 수렴합니다.
# * 전이 학습을 위해서는, 사전 학습된(pre-trained) 네트워크와 동일한 크기의 입력 차원을 갖도록 <b>데이터셋을 수정</b>해야 합니다.
#     * ResNet 특성상 데이터셋 수정 없이도 동작할 수 있지만, 일반적으로 데이터셋을 수정합니다.
# * (참고) [PyTorch 공식 Transfer Learning 튜토리얼](https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html)
# * 기본적인 Transfer Learning을 이용해 91~93%의 정확도를 얻을 수 있습니다.

# %%
transforms_train_transferred = transforms.Compose([
    transforms.RandomResizedCrop((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) # 정규화(normalization)
])

transforms_val_transferred = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

train_dataset_transferred = datasets.ImageFolder(train_path, transforms_train_transferred)
val_dataset_transferred = datasets.ImageFolder(val_path, transforms_val_transferred)

train_dataloader_transferred = torch.utils.data.DataLoader(train_dataset_transferred, batch_size=16, shuffle=True, num_workers=2)
val_dataloader_transferred = torch.utils.data.DataLoader(val_dataset_transferred, batch_size=16, shuffle=True, num_workers=2)

print('Training dataset size:', len(train_dataset_transferred))
print('Validation dataset size:', len(val_dataset_transferred))

class_names = train_dataset_transferred.classes
print('Class names:', class_names)
# Out:
# Training dataset size: 13627
# Validation dataset size: 3407
# Class names: ['buildings', 'forests', 'glacier', 'mountains', 'sea', 'street']

# %%
net = torchvision.models.resnet18(pretrained=True)

# 마지막 레이어의 차원을 6차원으로 조절
num_features = net.fc.in_features
net.fc = nn.Linear(num_features, 6)
net = net.to(device)

epoch = 20
learning_rate = 0.001 # 일반적으로 fine-tuning을 진행할 때는 학습률(learning rate)을 낮게 설정
file_name = "ResNet18Transferred.pt"

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)

train_result = []
val_result = []

start_time = time.time() # 시작 시간

for i in range(epoch):
    train_acc, train_loss = train(net, i, optimizer, criterion, train_dataloader_transferred) # 학습(training)
    val_acc, val_loss = validate(net, i + 1, val_dataloader_transferred) # 검증(validation)

    # 학습된 모델 저장하기
    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print(f'Model saved! (time elapsed: {time.time() - start_time})')

    # 현재 epoch에서의 정확도(accuracy)와 손실(loss) 값 저장하기
    train_result.append((train_acc, train_loss))
    val_result.append((val_acc, val_loss))
# Out:
# [ Train epoch: 0 ]
# Train accuarcy: 76.73735965362883
# Train average loss: 0.03927191147811609
# [ Validation epoch: 1 ]
# Accuarcy: 88.99324919283828
# Average loss: 0.01971462501815977
# Model saved! (time elapsed: 57.68897724151611)
# [ Train epoch: 1 ]
# Train accuarcy: 82.65208776693329
# Train average loss: 0.02987067018737882
# [ Validation epoch: 2 ]
# Accuarcy: 90.72497798649839
# Average loss: 0.016098890513715276
# Model saved! (time elapsed: 114.97562456130981)
# [ Train epoch: 2 ]
# Train accuarcy: 84.58207969472372
# Train average loss: 0.026206359815353027
# [ Validation epoch: 3 ]
# Accuarcy: 91.34135603169945
# Average loss: 0.01570589934555813
# Model saved! (time elapsed: 172.80669021606445)
# [ Train epoch: 3 ]
# Train accuarcy: 85.52139135539737
# Train average loss: 0.024795979192507644
# [ Validation epoch: 4 ]
# Accuarcy: 88.02465512180804
# Average loss: 0.022295160712753535
# Model saved! (time elapsed: 230.6609981060028)
# [ Train epoch: 4 ]
# Train accuarcy: 86.18184486680855
# Train average loss: 0.02377992051221562
# [ Validation epoch: 5 ]
# Accuarcy: 92.30995010272967
# Average loss: 0.014084740934960734
# Model saved! (time elapsed: 288.31283926963806)
# [ Train epoch: 5 ]
# Train accuarcy: 87.04043443164306
# Train average loss: 0.022508110433331393
# [ Validation epoch: 6 ]
# Accuarcy: 92.25124743175815
# Average loss: 0.01359202050597639
# Model saved! (time elapsed: 345.69286251068115)
# [ Train epoch: 6 ]
# Train accuarcy: 87.24590885741543
# Train average loss: 0.021195042326307187
# [ Validation epoch: 7 ]
# Accuarcy: 92.16319342530085
# Average loss: 0.014663816241332608
# Model saved! (time elapsed: 403.1283588409424)
# [ Train epoch: 7 ]
# Train accuarcy: 88.0824833052029
# Train average loss: 0.02046097561043436
# [ Validation epoch: 8 ]
# Accuarcy: 91.4587613736425
# Average loss: 0.015170558305997933
# Model saved! (time elapsed: 460.5742094516754)
# [ Train epoch: 8 ]
# Train accuarcy: 88.50077052909664
# Train average loss: 0.019577069311703655
# [ Validation epoch: 9 ]
# Accuarcy: 91.9577340769005
# Average loss: 0.014820666264320005
# Model saved! (time elapsed: 518.0491690635681)
# [ Train epoch: 9 ]
# Train accuarcy: 88.72092169956704
# Train average loss: 0.01915061301018335
# [ Validation epoch: 10 ]
# Accuarcy: 91.57616671558556
# Average loss: 0.015469911690453675
# Model saved! (time elapsed: 575.3326470851898)
# [ Train epoch: 10 ]
# Train accuarcy: 89.3226682321861
# Train average loss: 0.018218908906327425
# [ Validation epoch: 11 ]
# Accuarcy: 91.22395068975638
# Average loss: 0.016779066558510705
# Model saved! (time elapsed: 632.6658143997192)
# [ Train epoch: 11 ]
# Train accuarcy: 89.41806707272328
# Train average loss: 0.018030031635666213
# [ Validation epoch: 12 ]
# Accuarcy: 92.30995010272967
# Average loss: 0.0142230855012359
# Model saved! (time elapsed: 690.156346321106)
# [ Train epoch: 12 ]
# Train accuarcy: 89.57217289205255
# Train average loss: 0.017544450687229908
# [ Validation epoch: 13 ]
# Accuarcy: 91.5468153800998
# Average loss: 0.01602759961700895
# Model saved! (time elapsed: 747.4825925827026)
# [ Train epoch: 13 ]
# Train accuarcy: 89.81433917956997
# Train average loss: 0.017362345219721333
# [ Validation epoch: 14 ]
# Accuarcy: 92.42735544467273
# Average loss: 0.014935790816453727
# Model saved! (time elapsed: 804.6730387210846)
# [ Train epoch: 14 ]
# Train accuarcy: 90.18125779702062
# Train average loss: 0.016613503814373997
# [ Validation epoch: 15 ]
# Accuarcy: 92.01643674787204
# Average loss: 0.014743978859616718
# Model saved! (time elapsed: 861.9378566741943)
# [ Train epoch: 15 ]
# Train accuarcy: 90.54083804212226
# Train average loss: 0.016090837766955537
# [ Validation epoch: 16 ]
# Accuarcy: 91.98708541238626
# Average loss: 0.01607457565160516
# Model saved! (time elapsed: 919.4103908538818)
# [ Train epoch: 16 ]
# Train accuarcy: 90.46011594628311
# Train average loss: 0.01598841757304792
# [ Validation epoch: 17 ]
# Accuarcy: 92.51540945113003
# Average loss: 0.014857837464182034
# Model saved! (time elapsed: 976.765958070755)
# [ Train epoch: 17 ]
# Train accuarcy: 90.54083804212226
# Train average loss: 0.016162408172382778
# [ Validation epoch: 18 ]
# Accuarcy: 93.3665981802172
# Average loss: 0.013948299775530438
# Model saved! (time elapsed: 1034.075897693634)
# [ Train epoch: 18 ]
# Train accuarcy: 90.84171130843178
# Train average loss: 0.015477191083490795
# [ Validation epoch: 19 ]
# Accuarcy: 91.0478426768418
# Average loss: 0.017144537862419804
# Model saved! (time elapsed: 1091.335037469864)
# [ Train epoch: 19 ]
# Train accuarcy: 91.06186247890219
# Train average loss: 0.015025704684121562
# [ Validation epoch: 20 ]
# Accuarcy: 92.07513941884356
# Average loss: 0.016079544070838846
# Model saved! (time elapsed: 1148.6852900981903)

# %% [markdown]
# #### <b>Problem 7. State-of-the-Art 성능 만들기</b>
#
# * SOTA 수준의 성능을 만들어 보세요.
# * (참고) Transfer Learning과 Mixup을 함께 사용해 보세요.
#     * 더 큰 규모의 사전 학습된 모델(ResNet-50 이상)을 이용해 보세요.
# * (참고) learning rate scheduler를 사용해 보세요.
#
# <pre>
# def adjust_learning_rate(optimizer, epoch):
#     lr = learning_rate
#     if epoch >= 20:
#         lr /= 8
#     if epoch >= 40:
#         lr /= 8
#     for param_group in optimizer.param_groups:
#         param_group['lr'] = lr
# </pre>
#
# * 대회(competition)에 참여하고 있다고 생각하고, <b>94% 이상의 정확도</b>를 만들어 보세요.
#     * 내 모델의 검증 정확도(validation accuracy): {답을 쓰세요.}

# %%
from torchvision import models
import torch

resnet50_pretrained = models.resnet50(pretrained=True)

print(resnet50_pretrained)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 116MB/s]
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
def adjust_learning_rate(optimizer, epoch):
    lr = learning_rate
    if epoch >= 20:
        lr /= 8
    if epoch >= 40:
        lr /= 8
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

# %%
net = torchvision.models.resnet50(pretrained=True)

# 마지막 레이어의 차원을 6차원으로 조절
num_features = net.fc.in_features
net.fc = nn.Linear(num_features, 6)
net = net.to(device)

epoch = 30
learning_rate = 0.001
file_name = "CustomResnetModel.pt"

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)

train_result = []
val_result = []

start_time = time.time() # 시작 시간

for i in range(epoch):
    train_acc, train_loss = train_with_mixup(net, i, optimizer, criterion, train_dataloader_transferred) # 학습(training)
    val_acc, val_loss = validate(net, i + 1, val_dataloader_transferred) # 검증(validation)
    adjust_learning_rate(optimizer,i)
    # 학습된 모델 저장하기
    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print(f'Model saved! (time elapsed: {time.time() - start_time})')

    # 현재 epoch에서의 정확도(accuracy)와 손실(loss) 값 저장하기
    train_result.append((train_acc, train_loss))
    val_result.append((val_acc, val_loss))
# Out:
# [ Train epoch: 0 ]
# Train accuarcy: 60.62553486286632
# Train average loss: 0.07111036637090593
# [ Validation epoch: 1 ]
# Accuarcy: 89.93249192838275
# Average loss: 0.02324319956919858
# Model saved! (time elapsed: 150.84946489334106)
# [ Train epoch: 1 ]
# Train accuarcy: 64.83143535951928
# Train average loss: 0.0648917939562856
# [ Validation epoch: 2 ]
# Accuarcy: 90.63692398004109
# Average loss: 0.021737870381117776
# Model saved! (time elapsed: 302.4716947078705)
# [ Train epoch: 2 ]
# Train accuarcy: 65.96092372701214
# Train average loss: 0.0626526868548057
# [ Validation epoch: 3 ]
# Accuarcy: 91.31200469621368
# Average loss: 0.020256585952978103
# Model saved! (time elapsed: 454.4303958415985)
# [ Train epoch: 3 ]
# Train accuarcy: 66.25408639058362
# Train average loss: 0.06182585832368796
# [ Validation epoch: 4 ]
# Accuarcy: 92.07513941884356
# Average loss: 0.02018329009767988
# Model saved! (time elapsed: 606.4024124145508)
# [ Train epoch: 4 ]
# Train accuarcy: 67.41661210595856
# Train average loss: 0.059754750506757354
# [ Validation epoch: 5 ]
# Accuarcy: 89.84443792192545
# Average loss: 0.021785172079188193
# Model saved! (time elapsed: 757.9463329315186)
# [ Train epoch: 5 ]
# Train accuarcy: 67.46719705505646
# Train average loss: 0.05943722654208667
# [ Validation epoch: 6 ]
# Accuarcy: 92.75022013501615
# Average loss: 0.01720815181233577
# Model saved! (time elapsed: 909.9537003040314)
# [ Train epoch: 6 ]
# Train accuarcy: 68.19169454852607
# Train average loss: 0.05790748892180715
# [ Validation epoch: 7 ]
# Accuarcy: 92.28059876724392
# Average loss: 0.017748918973668287
# Model saved! (time elapsed: 1061.7388987541199)
# [ Train epoch: 7 ]
# Train accuarcy: 68.74189507105041
# Train average loss: 0.05667628524802423
# [ Validation epoch: 8 ]
# Accuarcy: 92.5447607866158
# Average loss: 0.016827602992405596
# Model saved! (time elapsed: 1213.495100736618)
# [ Train epoch: 8 ]
# Train accuarcy: 68.6640889462413
# Train average loss: 0.056927806481477355
# [ Validation epoch: 9 ]
# Accuarcy: 91.48811270912826
# Average loss: 0.019159075446778952
# Model saved! (time elapsed: 1365.0233962535858)
# [ Train epoch: 9 ]
# Train accuarcy: 68.78169795432306
# Train average loss: 0.05655746306280069
# [ Validation epoch: 10 ]
# Accuarcy: 92.16319342530085
# Average loss: 0.018514619957046632
# Model saved! (time elapsed: 1517.1063582897186)
# [ Train epoch: 10 ]
# Train accuarcy: 69.15107230760553
# Train average loss: 0.05625333360725675
# [ Validation epoch: 11 ]
# Accuarcy: 91.57616671558556
# Average loss: 0.019900909583170392
# Model saved! (time elapsed: 1670.5986540317535)
# [ Train epoch: 11 ]
# Train accuarcy: 69.63946593653718
# Train average loss: 0.05548744756623708
# [ Validation epoch: 12 ]
# Accuarcy: 92.80892280598768
# Average loss: 0.018155615828168124
# Model saved! (time elapsed: 1822.606055021286)
# [ Train epoch: 12 ]
# Train accuarcy: 69.34146775071508
# Train average loss: 0.05547812937216144
# [ Validation epoch: 13 ]
# Accuarcy: 92.13384208981509
# Average loss: 0.019479992922744268
# Model saved! (time elapsed: 1974.3644814491272)
# [ Train epoch: 13 ]
# Train accuarcy: 69.8151929870326
# Train average loss: 0.05498517814176469
# [ Validation epoch: 14 ]
# Accuarcy: 92.95567948341649
# Average loss: 0.01705439701252121
# Model saved! (time elapsed: 2126.109452486038)
# [ Train epoch: 14 ]
# Train accuarcy: 68.93931600440429
# Train average loss: 0.05586189267688183
# [ Validation epoch: 15 ]
# Accuarcy: 92.92632814793073
# Average loss: 0.016762964635221426
# Model saved! (time elapsed: 2278.043152332306)
# [ Train epoch: 15 ]
# Train accuarcy: 69.7627788423791
# Train average loss: 0.054762825305318244
# [ Validation epoch: 16 ]
# Accuarcy: 92.7795714705019
# Average loss: 0.018675475315436053
# Model saved! (time elapsed: 2429.874111175537)
# [ Train epoch: 16 ]
# Train accuarcy: 70.62849272926968
# Train average loss: 0.053621175002306426
# [ Validation epoch: 17 ]
# Accuarcy: 91.31200469621368
# Average loss: 0.01997451691953605
# Model saved! (time elapsed: 2581.744337081909)
# [ Train epoch: 17 ]
# Train accuarcy: 70.07296109390325
# Train average loss: 0.05450396710182396
# [ Validation epoch: 18 ]
# Accuarcy: 92.83827414147343
# Average loss: 0.017629254258357784
# Model saved! (time elapsed: 2733.4976723194122)
# [ Train epoch: 18 ]
# Train accuarcy: 69.86485860578983
# Train average loss: 0.054458786406012795
# [ Validation epoch: 19 ]
# Accuarcy: 93.39594951570297
# Average loss: 0.015859968704424333
# Model saved! (time elapsed: 2885.781254053116)
# [ Train epoch: 19 ]
# Train accuarcy: 70.71880094639391
# Train average loss: 0.05291012202340946
# [ Validation epoch: 20 ]
# Accuarcy: 93.13178749633109
# Average loss: 0.017034775474430493
# Model saved! (time elapsed: 3038.0178525447845)
# [ Train epoch: 20 ]
# Train accuarcy: 70.84773791060768
# Train average loss: 0.052787600197633365
# [ Validation epoch: 21 ]
# Accuarcy: 93.21984150278837
# Average loss: 0.015928724230140544
# Model saved! (time elapsed: 3189.915515899658)
# [ Train epoch: 21 ]
# Train accuarcy: 71.36300868634305
# Train average loss: 0.05158107292825341
# [ Validation epoch: 22 ]
# Accuarcy: 93.74816554153215
# Average loss: 0.014911698617559394
# Model saved! (time elapsed: 3341.9208879470825)
# [ Train epoch: 22 ]
# Train accuarcy: 71.31994273833688
# Train average loss: 0.05159323058960644
# [ Validation epoch: 23 ]
# Accuarcy: 93.92427355444673
# Average loss: 0.015405166952148854
# Model saved! (time elapsed: 3494.232736349106)
# [ Train epoch: 23 ]
# Train accuarcy: 70.88991176434563
# Train average loss: 0.051960206497303416
# [ Validation epoch: 24 ]
# Accuarcy: 94.01232756090403
# Average loss: 0.015195161829141357
# Model saved! (time elapsed: 3646.6801376342773)
# [ Train epoch: 24 ]
# Train accuarcy: 71.53130052309643
# Train average loss: 0.05105172256186168
# [ Validation epoch: 25 ]
# Accuarcy: 93.98297622541826
# Average loss: 0.014948584831483489
# Model saved! (time elapsed: 3798.884137868881)
# [ Train epoch: 25 ]
# Train accuarcy: 71.47073238462741
# Train average loss: 0.05098297802135846
# [ Validation epoch: 26 ]
# Accuarcy: 94.10038156736131
# Average loss: 0.015246122515652933
# Model saved! (time elapsed: 3951.368909597397)
# [ Train epoch: 26 ]
# Train accuarcy: 72.06374642718247
# Train average loss: 0.05021066916761372
# [ Validation epoch: 27 ]
# Accuarcy: 93.51335485764602
# Average loss: 0.016122927188890787
# Model saved! (time elapsed: 4103.98046374321)
# [ Train epoch: 27 ]
# Train accuarcy: 71.03547119257104
# Train average loss: 0.05123311493999848
# [ Validation epoch: 28 ]
# Accuarcy: 94.04167889638978
# Average loss: 0.014839650239190785
# Model saved! (time elapsed: 4256.45275759697)
# [ Train epoch: 28 ]
# Train accuarcy: 71.91677041948927
# Train average loss: 0.05021268928097797
# [ Validation epoch: 29 ]
# Accuarcy: 94.07103023187555
# Average loss: 0.01494143672543325
# Model saved! (time elapsed: 4408.678342342377)
# [ Train epoch: 29 ]
# Train accuarcy: 72.07631676036048
# Train average loss: 0.05060487354550558
# [ Validation epoch: 30 ]
# Accuarcy: 94.10038156736131
# Average loss: 0.014789678347724815
# Model saved! (time elapsed: 4560.67885684967)
